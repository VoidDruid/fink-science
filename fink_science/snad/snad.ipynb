# %% [markdown]
# # Science modules in Fink: an example
#
# A science module contains necessary routines and classes to process the data, and add values. Typically, you will receive alerts in input, and output the same alerts with additional information. Input alert information contains position, flux, telescope properties, ... You can find what information is available in an alert [here](https://zwickytransientfacility.github.io/ztf-avro-alert/), or check the current [Fink added values](https://fink-broker.readthedocs.io/en/latest/science/added_values/).
#
# In this simple example, we explore a simple science module that takes magnitudes contained in each alert, and computes the change in magnitude between the last two measurements.

# %%
# utility from fink-science
from fink_science.utilities import concat_col

# %% [markdown]
# ## Loading the data
#
# Fink receives data as Avro. However, the internal processing makes use of Parquet files. We provide here alert data as Parquet: it contains original alert data from ZTF and some added values from Fink:

# %%
# Load the data into a Spark DataFrame
df = spark.read.format('parquet').load('sample.parquet')
# Out:
# 22/01/24 00:15:04 INFO InMemoryFileIndex: It took 32 ms to list leaf files for 1 paths.
# 22/01/24 00:15:04 INFO SparkContext: Starting job: load at NativeMethodAccessorImpl.java:0
# 22/01/24 00:15:04 INFO DAGScheduler: Got job 0 (load at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 22/01/24 00:15:04 INFO DAGScheduler: Final stage: ResultStage 0 (load at NativeMethodAccessorImpl.java:0)
# 22/01/24 00:15:04 INFO DAGScheduler: Parents of final stage: List()
# 22/01/24 00:15:04 INFO DAGScheduler: Missing parents: List()
# 22/01/24 00:15:04 INFO DAGScheduler: Submitting ResultStage 0 (MapPartitionsRDD[1] at load at NativeMethodAccessorImpl.java:0), which has no missing parents
# 22/01/24 00:15:04 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 93.1 KB, free 366.2 MB)
# 22/01/24 00:15:04 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 31.2 KB, free 366.2 MB)
# 22/01/24 00:15:04 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on 192.168.0.111:62599 (size: 31.2 KB, free: 366.3 MB)
# 22/01/24 00:15:04 INFO SparkContext: Created broadcast 0 from broadcast at DAGScheduler.scala:1184
# 22/01/24 00:15:04 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 0 (MapPartitionsRDD[1] at load at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 22/01/24 00:15:04 INFO TaskSchedulerImpl: Adding task set 0.0 with 1 tasks
# 22/01/24 00:15:04 INFO TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0, localhost, executor driver, partition 0, PROCESS_LOCAL, 8107 bytes)
# 22/01/24 00:15:04 INFO Executor: Running task 0.0 in stage 0.0 (TID 0)
# 22/01/24 00:15:04 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.commons_commons-crypto-1.0.0.jar with timestamp 1642972498663
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.commons_commons-crypto-1.0.0.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.commons_commons-crypto-1.0.0.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.codehaus.jackson_jackson-xc-1.9.13.jar with timestamp 1642972498957
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.codehaus.jackson_jackson-xc-1.9.13.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.codehaus.jackson_jackson-xc-1.9.13.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.kafka_kafka-clients-2.0.0.jar with timestamp 1642972498450
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.kafka_kafka-clients-2.0.0.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.kafka_kafka-clients-2.0.0.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/com.sun.jersey_jersey-client-1.9.jar with timestamp 1642972498929
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/com.sun.jersey_jersey-client-1.9.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.sun.jersey_jersey-client-1.9.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/com.sun.jersey.contribs_jersey-guice-1.9.jar with timestamp 1642972498991
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/com.sun.jersey.contribs_jersey-guice-1.9.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.sun.jersey.contribs_jersey-guice-1.9.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.slf4j_slf4j-log4j12-1.7.25.jar with timestamp 1642972498700
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.slf4j_slf4j-log4j12-1.7.25.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.slf4j_slf4j-log4j12-1.7.25.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar with timestamp 1642972498836
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/log4j_log4j-1.2.17.jar with timestamp 1642972498707
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/log4j_log4j-1.2.17.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/log4j_log4j-1.2.17.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/aopalliance_aopalliance-1.0.jar with timestamp 1642972499011
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/aopalliance_aopalliance-1.0.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/aopalliance_aopalliance-1.0.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/com.sun.jersey_jersey-json-1.9.jar with timestamp 1642972498985
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/com.sun.jersey_jersey-json-1.9.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.sun.jersey_jersey-json-1.9.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/asm_asm-3.2.jar with timestamp 1642972499025
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/asm_asm-3.2.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/asm_asm-3.2.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/com.github.stephenc.findbugs_findbugs-annotations-1.3.9-1.jar with timestamp 1642972498814
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/com.github.stephenc.findbugs_findbugs-annotations-1.3.9-1.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.github.stephenc.findbugs_findbugs-annotations-1.3.9-1.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.spark_spark-sql-kafka-0-10_2.11-2.4.4.jar with timestamp 1642972498380
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.spark_spark-sql-kafka-0-10_2.11-2.4.4.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.spark_spark-sql-kafka-0-10_2.11-2.4.4.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.hbase.thirdparty_hbase-shaded-miscellaneous-2.1.0.jar with timestamp 1642972498571
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.hbase.thirdparty_hbase-shaded-miscellaneous-2.1.0.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hbase.thirdparty_hbase-shaded-miscellaneous-2.1.0.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.hadoop_hadoop-annotations-2.7.7.jar with timestamp 1642972498854
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.hadoop_hadoop-annotations-2.7.7.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hadoop_hadoop-annotations-2.7.7.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.commons_commons-compress-1.4.1.jar with timestamp 1642972498895
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.commons_commons-compress-1.4.1.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.commons_commons-compress-1.4.1.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.commons_commons-lang3-3.6.jar with timestamp 1642972498555
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.commons_commons-lang3-3.6.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.commons_commons-lang3-3.6.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.directory.api_api-util-1.0.0-M20.jar with timestamp 1642972498779
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.directory.api_api-util-1.0.0-M20.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.directory.api_api-util-1.0.0-M20.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/com.fasterxml.jackson.core_jackson-annotations-2.9.2.jar with timestamp 1642972498714
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/com.fasterxml.jackson.core_jackson-annotations-2.9.2.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.fasterxml.jackson.core_jackson-annotations-2.9.2.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.hbase_hbase-replication-2.1.4.jar with timestamp 1642972498820
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.hbase_hbase-replication-2.1.4.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hbase_hbase-replication-2.1.4.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.yetus_audience-annotations-0.5.0.jar with timestamp 1642972498686
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.yetus_audience-annotations-0.5.0.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.yetus_audience-annotations-0.5.0.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.zookeeper_zookeeper-3.4.10.jar with timestamp 1642972498613
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.zookeeper_zookeeper-3.4.10.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.zookeeper_zookeeper-3.4.10.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.directory.api_api-asn1-api-1.0.0-M20.jar with timestamp 1642972498772
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.directory.api_api-asn1-api-1.0.0-M20.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.directory.api_api-asn1-api-1.0.0-M20.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/javax.inject_javax.inject-1.jar with timestamp 1642972499003
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/javax.inject_javax.inject-1.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/javax.inject_javax.inject-1.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.hbase_hbase-client-2.1.4.jar with timestamp 1642972498412
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.hbase_hbase-client-2.1.4.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hbase_hbase-client-2.1.4.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.xerial.snappy_snappy-java-1.1.7.3.jar with timestamp 1642972498469
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.xerial.snappy_snappy-java-1.1.7.3.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.xerial.snappy_snappy-java-1.1.7.3.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.spark_spark-streaming-kafka-0-10-assembly_2.11-2.4.4.jar with timestamp 1642972498356
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.spark_spark-streaming-kafka-0-10-assembly_2.11-2.4.4.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.spark_spark-streaming-kafka-0-10-assembly_2.11-2.4.4.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.spark-project.spark_unused-1.0.0.jar with timestamp 1642972498443
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.spark-project.spark_unused-1.0.0.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.spark-project.spark_unused-1.0.0.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.curator_curator-framework-4.0.0.jar with timestamp 1642972498745
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.curator_curator-framework-4.0.0.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.curator_curator-framework-4.0.0.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.mortbay.jetty_jetty-util-6.1.26.jar with timestamp 1642972498915
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.mortbay.jetty_jetty-util-6.1.26.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.mortbay.jetty_jetty-util-6.1.26.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/javax.servlet_servlet-api-2.5.jar with timestamp 1642972498909
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/javax.servlet_servlet-api-2.5.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/javax.servlet_servlet-api-2.5.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/commons-codec_commons-codec-1.10.jar with timestamp 1642972498539
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/commons-codec_commons-codec-1.10.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/commons-codec_commons-codec-1.10.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.slf4j_slf4j-api-1.7.25.jar with timestamp 1642972498564
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.slf4j_slf4j-api-1.7.25.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.slf4j_slf4j-api-1.7.25.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/commons-lang_commons-lang-2.6.jar with timestamp 1642972498902
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/commons-lang_commons-lang-2.6.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/commons-lang_commons-lang-2.6.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/Work/snad/fink-broker/conf/hbase-site.xml with timestamp 1642972498340
# 22/01/24 00:15:05 INFO Utils: /Users/igor/Work/snad/fink-broker/conf/hbase-site.xml has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/hbase-site.xml
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/io.dropwizard.metrics_metrics-core-3.2.1.jar with timestamp 1642972498649
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/io.dropwizard.metrics_metrics-core-3.2.1.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/io.dropwizard.metrics_metrics-core-3.2.1.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.curator_curator-client-4.0.0.jar with timestamp 1642972498785
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.curator_curator-client-4.0.0.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.curator_curator-client-4.0.0.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.hbase.thirdparty_hbase-shaded-protobuf-2.1.0.jar with timestamp 1642972498486
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.hbase.thirdparty_hbase-shaded-protobuf-2.1.0.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hbase.thirdparty_hbase-shaded-protobuf-2.1.0.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/commons-io_commons-io-2.5.jar with timestamp 1642972498548
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/commons-io_commons-io-2.5.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/commons-io_commons-io-2.5.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.hamcrest_hamcrest-core-1.3.jar with timestamp 1642972498693
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.hamcrest_hamcrest-core-1.3.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.hamcrest_hamcrest-core-1.3.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.lz4_lz4-java-1.4.0.jar with timestamp 1642972498462
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.lz4_lz4-java-1.4.0.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.lz4_lz4-java-1.4.0.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/com.google.guava_guava-11.0.2.jar with timestamp 1642972498797
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/com.google.guava_guava-11.0.2.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.google.guava_guava-11.0.2.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/com.sun.jersey_jersey-server-1.9.jar with timestamp 1642972498978
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/com.sun.jersey_jersey-server-1.9.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.sun.jersey_jersey-server-1.9.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.codehaus.jettison_jettison-1.3.8.jar with timestamp 1642972499031
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.codehaus.jettison_jettison-1.3.8.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.codehaus.jettison_jettison-1.3.8.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/com.sun.xml.bind_jaxb-impl-2.2.3-1.jar with timestamp 1642972499037
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/com.sun.xml.bind_jaxb-impl-2.2.3-1.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.sun.xml.bind_jaxb-impl-2.2.3-1.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.hbase.thirdparty_hbase-shaded-netty-2.1.0.jar with timestamp 1642972498597
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.hbase.thirdparty_hbase-shaded-netty-2.1.0.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hbase.thirdparty_hbase-shaded-netty-2.1.0.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.codehaus.jackson_jackson-core-asl-1.9.13.jar with timestamp 1642972498935
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.codehaus.jackson_jackson-core-asl-1.9.13.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.codehaus.jackson_jackson-core-asl-1.9.13.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.directory.server_apacheds-i18n-2.0.0-M15.jar with timestamp 1642972498766
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.directory.server_apacheds-i18n-2.0.0-M15.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.directory.server_apacheds-i18n-2.0.0-M15.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.tukaani_xz-1.0.jar with timestamp 1642972498997
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.tukaani_xz-1.0.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.tukaani_xz-1.0.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.jruby.jcodings_jcodings-1.0.18.jar with timestamp 1642972498632
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.jruby.jcodings_jcodings-1.0.18.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.jruby.jcodings_jcodings-1.0.18.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.hadoop_hadoop-auth-2.7.7.jar with timestamp 1642972498679
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.hadoop_hadoop-auth-2.7.7.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hadoop_hadoop-auth-2.7.7.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/com.google.inject_guice-3.0.jar with timestamp 1642972498970
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/com.google.inject_guice-3.0.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.google.inject_guice-3.0.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.httpcomponents_httpcore-4.4.6.jar with timestamp 1642972498751
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.httpcomponents_httpcore-4.4.6.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.httpcomponents_httpcore-4.4.6.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/io.netty_netty-3.6.2.Final.jar with timestamp 1642972498868
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/io.netty_netty-3.6.2.Final.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/io.netty_netty-3.6.2.Final.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.hbase_hbase-common-2.1.4.jar with timestamp 1642972498425
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.hbase_hbase-common-2.1.4.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hbase_hbase-common-2.1.4.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/javax.xml.bind_jaxb-api-2.2.12.jar with timestamp 1642972498888
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/javax.xml.bind_jaxb-api-2.2.12.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/javax.xml.bind_jaxb-api-2.2.12.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/com.fasterxml.jackson.core_jackson-core-2.9.2.jar with timestamp 1642972498721
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/com.fasterxml.jackson.core_jackson-core-2.9.2.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.fasterxml.jackson.core_jackson-core-2.9.2.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.codehaus.jackson_jackson-mapper-asl-1.9.13.jar with timestamp 1642972498943
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.codehaus.jackson_jackson-mapper-asl-1.9.13.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.codehaus.jackson_jackson-mapper-asl-1.9.13.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar with timestamp 1642972498827
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hadoop_hadoop-mapreduce-client-core-2.7.7.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/com.fasterxml.jackson.core_jackson-databind-2.9.2.jar with timestamp 1642972498670
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/com.fasterxml.jackson.core_jackson-databind-2.9.2.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.fasterxml.jackson.core_jackson-databind-2.9.2.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.hbase_hbase-protocol-shaded-2.1.4.jar with timestamp 1642972498503
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.hbase_hbase-protocol-shaded-2.1.4.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hbase_hbase-protocol-shaded-2.1.4.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/com.google.inject.extensions_guice-servlet-3.0.jar with timestamp 1642972498862
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/com.google.inject.extensions_guice-servlet-3.0.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.google.inject.extensions_guice-servlet-3.0.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/junit_junit-4.12.jar with timestamp 1642972498655
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/junit_junit-4.12.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/junit_junit-4.12.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.hbase_hbase-protocol-2.1.4.jar with timestamp 1642972498524
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.hbase_hbase-protocol-2.1.4.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hbase_hbase-protocol-2.1.4.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/com.google.protobuf_protobuf-java-2.5.0.jar with timestamp 1642972498586
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/com.google.protobuf_protobuf-java-2.5.0.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.google.protobuf_protobuf-java-2.5.0.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.directory.server_apacheds-kerberos-codec-2.0.0-M15.jar with timestamp 1642972498736
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.directory.server_apacheds-kerberos-codec-2.0.0-M15.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.directory.server_apacheds-kerberos-codec-2.0.0-M15.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.sonatype.sisu.inject_cglib-2.2.1-v20090111.jar with timestamp 1642972499017
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.sonatype.sisu.inject_cglib-2.2.1-v20090111.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.sonatype.sisu.inject_cglib-2.2.1-v20090111.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/com.thoughtworks.paranamer_paranamer-2.3.jar with timestamp 1642972499046
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/com.thoughtworks.paranamer_paranamer-2.3.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.thoughtworks.paranamer_paranamer-2.3.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.jruby.joni_joni-2.1.11.jar with timestamp 1642972498642
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.jruby.joni_joni-2.1.11.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.jruby.joni_joni-2.1.11.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/commons-logging_commons-logging-1.2.jar with timestamp 1642972498759
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/commons-logging_commons-logging-1.2.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/commons-logging_commons-logging-1.2.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/com.google.code.findbugs_jsr305-3.0.0.jar with timestamp 1642972498807
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/com.google.code.findbugs_jsr305-3.0.0.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.google.code.findbugs_jsr305-3.0.0.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.avro_avro-1.7.7.jar with timestamp 1642972498847
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.avro_avro-1.7.7.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.avro_avro-1.7.7.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/com.sun.jersey_jersey-core-1.9.jar with timestamp 1642972498922
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/com.sun.jersey_jersey-core-1.9.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.sun.jersey_jersey-core-1.9.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.hadoop_hadoop-yarn-api-2.7.7.jar with timestamp 1642972498878
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.hadoop_hadoop-yarn-api-2.7.7.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hadoop_hadoop-yarn-api-2.7.7.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.spark_spark-avro_2.11-2.4.4.jar with timestamp 1642972498402
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.spark_spark-avro_2.11-2.4.4.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.spark_spark-avro_2.11-2.4.4.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.codehaus.jackson_jackson-jaxrs-1.9.13.jar with timestamp 1642972498951
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.codehaus.jackson_jackson-jaxrs-1.9.13.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.codehaus.jackson_jackson-jaxrs-1.9.13.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.hbase_hbase-mapreduce-2.1.4.jar with timestamp 1642972498434
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.hbase_hbase-mapreduce-2.1.4.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hbase_hbase-mapreduce-2.1.4.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.htrace_htrace-core4-4.2.0-incubating.jar with timestamp 1642972498621
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.htrace_htrace-core4-4.2.0-incubating.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.htrace_htrace-core4-4.2.0-incubating.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/org.apache.httpcomponents_httpclient-4.5.3.jar with timestamp 1642972498728
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/org.apache.httpcomponents_httpclient-4.5.3.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.httpcomponents_httpclient-4.5.3.jar
# 22/01/24 00:15:05 INFO Executor: Fetching file:///Users/igor/.ivy2/jars/commons-cli_commons-cli-1.2.jar with timestamp 1642972498964
# 22/01/24 00:15:05 INFO Utils: /Users/igor/.ivy2/jars/commons-cli_commons-cli-1.2.jar has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/commons-cli_commons-cli-1.2.jar
# 22/01/24 00:15:05 INFO Executor: Fetching spark://192.168.0.111:62598/jars/asm_asm-3.2.jar with timestamp 1642972498316
# 22/01/24 00:15:05 INFO TransportClientFactory: Successfully created connection to /192.168.0.111:62598 after 40 ms (0 ms spent in bootstraps)
# 22/01/24 00:15:05 INFO Utils: Fetching spark://192.168.0.111:62598/jars/asm_asm-3.2.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp9144522615365052735.tmp
# 22/01/24 00:15:05 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp9144522615365052735.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/asm_asm-3.2.jar
# 22/01/24 00:15:05 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/asm_asm-3.2.jar to class loader
# 22/01/24 00:15:05 INFO Executor: Fetching spark://192.168.0.111:62598/jars/com.google.guava_guava-11.0.2.jar with timestamp 1642972498313
# 22/01/24 00:15:05 INFO Utils: Fetching spark://192.168.0.111:62598/jars/com.google.guava_guava-11.0.2.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp6901618123766344268.tmp
# 22/01/24 00:15:05 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp6901618123766344268.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.google.guava_guava-11.0.2.jar
# 22/01/24 00:15:05 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.google.guava_guava-11.0.2.jar to class loader
# 22/01/24 00:15:05 INFO Executor: Fetching spark://192.168.0.111:62598/jars/org.codehaus.jackson_jackson-core-asl-1.9.13.jar with timestamp 1642972498314
# 22/01/24 00:15:05 INFO Utils: Fetching spark://192.168.0.111:62598/jars/org.codehaus.jackson_jackson-core-asl-1.9.13.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp368671782147704539.tmp
# 22/01/24 00:15:05 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp368671782147704539.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.codehaus.jackson_jackson-core-asl-1.9.13.jar
# 22/01/24 00:15:05 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.codehaus.jackson_jackson-core-asl-1.9.13.jar to class loader
# 22/01/24 00:15:05 INFO Executor: Fetching spark://192.168.0.111:62598/jars/aopalliance_aopalliance-1.0.jar with timestamp 1642972498316
# 22/01/24 00:15:05 INFO Utils: Fetching spark://192.168.0.111:62598/jars/aopalliance_aopalliance-1.0.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp176041581224570042.tmp
# 22/01/24 00:15:05 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp176041581224570042.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/aopalliance_aopalliance-1.0.jar
# 22/01/24 00:15:05 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/aopalliance_aopalliance-1.0.jar to class loader
# 22/01/24 00:15:05 INFO Executor: Fetching spark://192.168.0.111:62598/jars/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar with timestamp 1642972498313
# 22/01/24 00:15:05 INFO Utils: Fetching spark://192.168.0.111:62598/jars/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp5141419608243325892.tmp
# 22/01/24 00:15:06 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp5141419608243325892.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar
# 22/01/24 00:15:06 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hadoop_hadoop-yarn-common-2.7.7.jar to class loader
# 22/01/24 00:15:06 INFO Executor: Fetching spark://192.168.0.111:62598/jars/org.apache.hbase.thirdparty_hbase-shaded-miscellaneous-2.1.0.jar with timestamp 1642972498308
# 22/01/24 00:15:06 INFO Utils: Fetching spark://192.168.0.111:62598/jars/org.apache.hbase.thirdparty_hbase-shaded-miscellaneous-2.1.0.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp4166718393225421481.tmp
# 22/01/24 00:15:06 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp4166718393225421481.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hbase.thirdparty_hbase-shaded-miscellaneous-2.1.0.jar
# 22/01/24 00:15:06 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hbase.thirdparty_hbase-shaded-miscellaneous-2.1.0.jar to class loader
# 22/01/24 00:15:06 INFO Executor: Fetching spark://192.168.0.111:62598/jars/org.apache.httpcomponents_httpcore-4.4.6.jar with timestamp 1642972498312
# 22/01/24 00:15:06 INFO Utils: Fetching spark://192.168.0.111:62598/jars/org.apache.httpcomponents_httpcore-4.4.6.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp4812760730708135636.tmp
# 22/01/24 00:15:06 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp4812760730708135636.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.httpcomponents_httpcore-4.4.6.jar
# 22/01/24 00:15:06 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.httpcomponents_httpcore-4.4.6.jar to class loader
# 22/01/24 00:15:06 INFO Executor: Fetching spark://192.168.0.111:62598/jars/org.hamcrest_hamcrest-core-1.3.jar with timestamp 1642972498311
# 22/01/24 00:15:06 INFO Utils: Fetching spark://192.168.0.111:62598/jars/org.hamcrest_hamcrest-core-1.3.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp1442305706707894804.tmp
# 22/01/24 00:15:06 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp1442305706707894804.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.hamcrest_hamcrest-core-1.3.jar
# 22/01/24 00:15:06 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.hamcrest_hamcrest-core-1.3.jar to class loader
# 22/01/24 00:15:06 INFO Executor: Fetching spark://192.168.0.111:62598/jars/com.sun.xml.bind_jaxb-impl-2.2.3-1.jar with timestamp 1642972498316
# 22/01/24 00:15:06 INFO Utils: Fetching spark://192.168.0.111:62598/jars/com.sun.xml.bind_jaxb-impl-2.2.3-1.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp7296441492865573726.tmp
# ...
# 22/01/24 00:15:06 INFO Executor: Fetching spark://192.168.0.111:62598/jars/com.sun.jersey_jersey-json-1.9.jar with timestamp 1642972498315
# 22/01/24 00:15:06 INFO Utils: Fetching spark://192.168.0.111:62598/jars/com.sun.jersey_jersey-json-1.9.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp8140239547915278048.tmp
# 22/01/24 00:15:06 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp8140239547915278048.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.sun.jersey_jersey-json-1.9.jar
# 22/01/24 00:15:06 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.sun.jersey_jersey-json-1.9.jar to class loader
# 22/01/24 00:15:06 INFO Executor: Fetching spark://192.168.0.111:62598/jars/io.dropwizard.metrics_metrics-core-3.2.1.jar with timestamp 1642972498309
# 22/01/24 00:15:06 INFO Utils: Fetching spark://192.168.0.111:62598/jars/io.dropwizard.metrics_metrics-core-3.2.1.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp1126880879251111296.tmp
# 22/01/24 00:15:06 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp1126880879251111296.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/io.dropwizard.metrics_metrics-core-3.2.1.jar
# 22/01/24 00:15:06 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/io.dropwizard.metrics_metrics-core-3.2.1.jar to class loader
# 22/01/24 00:15:06 INFO Executor: Fetching spark://192.168.0.111:62598/jars/org.apache.curator_curator-client-4.0.0.jar with timestamp 1642972498312
# 22/01/24 00:15:06 INFO Utils: Fetching spark://192.168.0.111:62598/jars/org.apache.curator_curator-client-4.0.0.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp7411426123329553968.tmp
# 22/01/24 00:15:06 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp7411426123329553968.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.curator_curator-client-4.0.0.jar
# 22/01/24 00:15:06 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.curator_curator-client-4.0.0.jar to class loader
# 22/01/24 00:15:06 INFO Executor: Fetching spark://192.168.0.111:62598/jars/log4j_log4j-1.2.17.jar with timestamp 1642972498311
# 22/01/24 00:15:06 INFO Utils: Fetching spark://192.168.0.111:62598/jars/log4j_log4j-1.2.17.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp8900908479237384111.tmp
# 22/01/24 00:15:06 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp8900908479237384111.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/log4j_log4j-1.2.17.jar
# 22/01/24 00:15:06 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/log4j_log4j-1.2.17.jar to class loader
# 22/01/24 00:15:06 INFO Executor: Fetching spark://192.168.0.111:62598/jars/javax.servlet_servlet-api-2.5.jar with timestamp 1642972498314
# 22/01/24 00:15:06 INFO Utils: Fetching spark://192.168.0.111:62598/jars/javax.servlet_servlet-api-2.5.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp8111872949390634852.tmp
# 22/01/24 00:15:06 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp8111872949390634852.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/javax.servlet_servlet-api-2.5.jar
# 22/01/24 00:15:06 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/javax.servlet_servlet-api-2.5.jar to class loader
# 22/01/24 00:15:06 INFO Executor: Fetching spark://192.168.0.111:62598/jars/commons-cli_commons-cli-1.2.jar with timestamp 1642972498315
# 22/01/24 00:15:06 INFO Utils: Fetching spark://192.168.0.111:62598/jars/commons-cli_commons-cli-1.2.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp8029828746762249453.tmp
# 22/01/24 00:15:06 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp8029828746762249453.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/commons-cli_commons-cli-1.2.jar
# 22/01/24 00:15:06 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/commons-cli_commons-cli-1.2.jar to class loader
# 22/01/24 00:15:06 INFO Executor: Fetching spark://192.168.0.111:62598/jars/commons-lang_commons-lang-2.6.jar with timestamp 1642972498314
# 22/01/24 00:15:06 INFO Utils: Fetching spark://192.168.0.111:62598/jars/commons-lang_commons-lang-2.6.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp8328960850677359358.tmp
# 22/01/24 00:15:06 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp8328960850677359358.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/commons-lang_commons-lang-2.6.jar
# 22/01/24 00:15:06 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/commons-lang_commons-lang-2.6.jar to class loader
# 22/01/24 00:15:06 INFO Executor: Fetching spark://192.168.0.111:62598/jars/com.sun.jersey_jersey-client-1.9.jar with timestamp 1642972498314
# 22/01/24 00:15:06 INFO Utils: Fetching spark://192.168.0.111:62598/jars/com.sun.jersey_jersey-client-1.9.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp6579942462588996824.tmp
# 22/01/24 00:15:06 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp6579942462588996824.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.sun.jersey_jersey-client-1.9.jar
# 22/01/24 00:15:06 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/com.sun.jersey_jersey-client-1.9.jar to class loader
# 22/01/24 00:15:06 INFO Executor: Fetching spark://192.168.0.111:62598/jars/org.apache.yetus_audience-annotations-0.5.0.jar with timestamp 1642972498310
# 22/01/24 00:15:06 INFO Utils: Fetching spark://192.168.0.111:62598/jars/org.apache.yetus_audience-annotations-0.5.0.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp24764465196957784.tmp
# 22/01/24 00:15:06 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp24764465196957784.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.yetus_audience-annotations-0.5.0.jar
# 22/01/24 00:15:06 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.yetus_audience-annotations-0.5.0.jar to class loader
# 22/01/24 00:15:06 INFO Executor: Fetching spark://192.168.0.111:62598/jars/org.apache.hadoop_hadoop-annotations-2.7.7.jar with timestamp 1642972498313
# 22/01/24 00:15:06 INFO Utils: Fetching spark://192.168.0.111:62598/jars/org.apache.hadoop_hadoop-annotations-2.7.7.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp2446706010020950537.tmp
# 22/01/24 00:15:06 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp2446706010020950537.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hadoop_hadoop-annotations-2.7.7.jar
# 22/01/24 00:15:06 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.hadoop_hadoop-annotations-2.7.7.jar to class loader
# 22/01/24 00:15:06 INFO Executor: Fetching spark://192.168.0.111:62598/jars/org.apache.httpcomponents_httpclient-4.5.3.jar with timestamp 1642972498311
# 22/01/24 00:15:06 INFO Utils: Fetching spark://192.168.0.111:62598/jars/org.apache.httpcomponents_httpclient-4.5.3.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp8263930602161830750.tmp
# 22/01/24 00:15:06 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp8263930602161830750.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.httpcomponents_httpclient-4.5.3.jar
# 22/01/24 00:15:06 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.httpcomponents_httpclient-4.5.3.jar to class loader
# 22/01/24 00:15:06 INFO Executor: Fetching spark://192.168.0.111:62598/jars/org.apache.spark_spark-sql-kafka-0-10_2.11-2.4.4.jar with timestamp 1642972498306
# 22/01/24 00:15:06 INFO Utils: Fetching spark://192.168.0.111:62598/jars/org.apache.spark_spark-sql-kafka-0-10_2.11-2.4.4.jar to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp1032098013445670343.tmp
# 22/01/24 00:15:06 INFO Utils: /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/fetchFileTemp1032098013445670343.tmp has been previously copied to /private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.spark_spark-sql-kafka-0-10_2.11-2.4.4.jar
# 22/01/24 00:15:06 INFO Executor: Adding file:/private/var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/spark-ba84ba15-c5fd-47a5-8afb-242e2603609d/userFiles-3727f4c9-a244-4edc-b983-c5a95a0e2987/org.apache.spark_spark-sql-kafka-0-10_2.11-2.4.4.jar to class loader
# 22/01/24 00:15:07 INFO Executor: Finished task 0.0 in stage 0.0 (TID 0). 9337 bytes result sent to driver
# 22/01/24 00:15:07 INFO TaskSetManager: Finished task 0.0 in stage 0.0 (TID 0) in 2164 ms on localhost (executor driver) (1/1)
# 22/01/24 00:15:07 INFO TaskSchedulerImpl: Removed TaskSet 0.0, whose tasks have all completed, from pool
# 22/01/24 00:15:07 INFO DAGScheduler: ResultStage 0 (load at NativeMethodAccessorImpl.java:0) finished in 2,481 s
# 22/01/24 00:15:07 INFO DAGScheduler: Job 0 finished: load at NativeMethodAccessorImpl.java:0, took 2,559361 s
# 22/01/24 00:15:07 INFO BlockManagerInfo: Removed broadcast_0_piece0 on 192.168.0.111:62599 in memory (size: 31.2 KB, free: 366.3 MB)
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 8
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 23
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 4
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 18
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 22
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 20
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 13
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 11
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 6
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 15
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 7
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 19
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 21
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 12
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 14
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 10
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 2
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 25
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 24
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 17
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 1
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 3
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 16
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 9
# 22/01/24 00:15:07 INFO ContextCleaner: Cleaned accumulator 5
# 22/01/24 00:15:08 WARN Utils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.debug.maxToStringFields' in SparkEnv.conf.

# %% [markdown]
# You can check what's in the data

# %%
df.printSchema()
# Out:
# root
#  |-- candid: long (nullable = true)
#  |-- schemavsn: string (nullable = true)
#  |-- publisher: string (nullable = true)
#  |-- objectId: string (nullable = true)
#  |-- candidate: struct (nullable = true)
#  |    |-- jd: double (nullable = true)
#  |    |-- fid: integer (nullable = true)
#  |    |-- pid: long (nullable = true)
#  |    |-- diffmaglim: float (nullable = true)
#  |    |-- pdiffimfilename: string (nullable = true)
#  |    |-- programpi: string (nullable = true)
#  |    |-- programid: integer (nullable = true)
#  |    |-- candid: long (nullable = true)
#  |    |-- isdiffpos: string (nullable = true)
#  |    |-- tblid: long (nullable = true)
#  |    |-- nid: integer (nullable = true)
#  |    |-- rcid: integer (nullable = true)
#  |    |-- field: integer (nullable = true)
#  |    |-- xpos: float (nullable = true)
#  |    |-- ypos: float (nullable = true)
#  |    |-- ra: double (nullable = true)
#  |    |-- dec: double (nullable = true)
#  |    |-- magpsf: float (nullable = true)
#  |    |-- sigmapsf: float (nullable = true)
#  |    |-- chipsf: float (nullable = true)
#  |    |-- magap: float (nullable = true)
#  |    |-- sigmagap: float (nullable = true)
#  |    |-- distnr: float (nullable = true)
#  |    |-- magnr: float (nullable = true)
#  |    |-- sigmagnr: float (nullable = true)
#  |    |-- chinr: float (nullable = true)
#  |    |-- sharpnr: float (nullable = true)
#  |    |-- sky: float (nullable = true)
#  |    |-- magdiff: float (nullable = true)
#  |    |-- fwhm: float (nullable = true)
#  |    |-- classtar: float (nullable = true)
#  |    |-- mindtoedge: float (nullable = true)
#  |    |-- magfromlim: float (nullable = true)
#  |    |-- seeratio: float (nullable = true)
#  |    |-- aimage: float (nullable = true)
#  |    |-- bimage: float (nullable = true)
#  |    |-- aimagerat: float (nullable = true)
#  |    |-- bimagerat: float (nullable = true)
#  |    |-- elong: float (nullable = true)
#  |    |-- nneg: integer (nullable = true)
#  |    |-- nbad: integer (nullable = true)
#  |    |-- rb: float (nullable = true)
#  |    |-- ssdistnr: float (nullable = true)
#  |    |-- ssmagnr: float (nullable = true)
#  |    |-- ssnamenr: string (nullable = true)
#  |    |-- sumrat: float (nullable = true)
#  |    |-- magapbig: float (nullable = true)
#  |    |-- sigmagapbig: float (nullable = true)
#  |    |-- ranr: double (nullable = true)
#  |    |-- decnr: double (nullable = true)
#  |    |-- sgmag1: float (nullable = true)
#  |    |-- srmag1: float (nullable = true)
#  |    |-- simag1: float (nullable = true)
#  |    |-- szmag1: float (nullable = true)
#  |    |-- sgscore1: float (nullable = true)
#  |    |-- distpsnr1: float (nullable = true)
#  |    |-- ndethist: integer (nullable = true)
#  |    |-- ncovhist: integer (nullable = true)
#  |    |-- jdstarthist: double (nullable = true)
#  |    |-- jdendhist: double (nullable = true)
#  |    |-- scorr: double (nullable = true)
#  |    |-- tooflag: integer (nullable = true)
#  |    |-- objectidps1: long (nullable = true)
#  |    |-- objectidps2: long (nullable = true)
#  |    |-- sgmag2: float (nullable = true)
#  |    |-- srmag2: float (nullable = true)
#  |    |-- simag2: float (nullable = true)
#  |    |-- szmag2: float (nullable = true)
#  |    |-- sgscore2: float (nullable = true)
#  |    |-- distpsnr2: float (nullable = true)
#  |    |-- objectidps3: long (nullable = true)
#  |    |-- sgmag3: float (nullable = true)
#  |    |-- srmag3: float (nullable = true)
#  |    |-- simag3: float (nullable = true)
#  |    |-- szmag3: float (nullable = true)
#  |    |-- sgscore3: float (nullable = true)
#  |    |-- distpsnr3: float (nullable = true)
#  |    |-- nmtchps: integer (nullable = true)
#  |    |-- rfid: long (nullable = true)
#  |    |-- jdstartref: double (nullable = true)
#  |    |-- jdendref: double (nullable = true)
#  |    |-- nframesref: integer (nullable = true)
#  |    |-- rbversion: string (nullable = true)
#  |    |-- dsnrms: float (nullable = true)
#  |    |-- ssnrms: float (nullable = true)
#  |    |-- dsdiff: float (nullable = true)
#  |    |-- magzpsci: float (nullable = true)
#  |    |-- magzpsciunc: float (nullable = true)
#  |    |-- magzpscirms: float (nullable = true)
#  |    |-- nmatches: integer (nullable = true)
#  |    |-- clrcoeff: float (nullable = true)
#  |    |-- clrcounc: float (nullable = true)
#  |    |-- zpclrcov: float (nullable = true)
#  |    |-- zpmed: float (nullable = true)
#  |    |-- clrmed: float (nullable = true)
#  |    |-- clrrms: float (nullable = true)
#  |    |-- neargaia: float (nullable = true)
#  |    |-- neargaiabright: float (nullable = true)
#  |    |-- maggaia: float (nullable = true)
#  |    |-- maggaiabright: float (nullable = true)
#  |    |-- exptime: float (nullable = true)
#  |    |-- drb: float (nullable = true)
#  |    |-- drbversion: string (nullable = true)
#  |-- prv_candidates: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- jd: double (nullable = true)
#  |    |    |-- fid: integer (nullable = true)
#  |    |    |-- pid: long (nullable = true)
#  |    |    |-- diffmaglim: float (nullable = true)
#  |    |    |-- pdiffimfilename: string (nullable = true)
#  |    |    |-- programpi: string (nullable = true)
#  |    |    |-- programid: integer (nullable = true)
#  |    |    |-- candid: long (nullable = true)
#  |    |    |-- isdiffpos: string (nullable = true)
#  |    |    |-- tblid: long (nullable = true)
#  |    |    |-- nid: integer (nullable = true)
#  |    |    |-- rcid: integer (nullable = true)
#  |    |    |-- field: integer (nullable = true)
#  |    |    |-- xpos: float (nullable = true)
#  |    |    |-- ypos: float (nullable = true)
#  |    |    |-- ra: double (nullable = true)
#  |    |    |-- dec: double (nullable = true)
#  |    |    |-- magpsf: float (nullable = true)
#  |    |    |-- sigmapsf: float (nullable = true)
#  |    |    |-- chipsf: float (nullable = true)
#  |    |    |-- magap: float (nullable = true)
#  |    |    |-- sigmagap: float (nullable = true)
#  |    |    |-- distnr: float (nullable = true)
#  |    |    |-- magnr: float (nullable = true)
#  |    |    |-- sigmagnr: float (nullable = true)
#  |    |    |-- chinr: float (nullable = true)
#  |    |    |-- sharpnr: float (nullable = true)
#  |    |    |-- sky: float (nullable = true)
#  |    |    |-- magdiff: float (nullable = true)
#  |    |    |-- fwhm: float (nullable = true)
#  |    |    |-- classtar: float (nullable = true)
#  |    |    |-- mindtoedge: float (nullable = true)
#  |    |    |-- magfromlim: float (nullable = true)
#  |    |    |-- seeratio: float (nullable = true)
#  |    |    |-- aimage: float (nullable = true)
#  |    |    |-- bimage: float (nullable = true)
#  |    |    |-- aimagerat: float (nullable = true)
#  |    |    |-- bimagerat: float (nullable = true)
#  |    |    |-- elong: float (nullable = true)
#  |    |    |-- nneg: integer (nullable = true)
#  |    |    |-- nbad: integer (nullable = true)
#  |    |    |-- rb: float (nullable = true)
#  |    |    |-- ssdistnr: float (nullable = true)
#  |    |    |-- ssmagnr: float (nullable = true)
#  |    |    |-- ssnamenr: string (nullable = true)
#  |    |    |-- sumrat: float (nullable = true)
#  |    |    |-- magapbig: float (nullable = true)
#  |    |    |-- sigmagapbig: float (nullable = true)
#  |    |    |-- ranr: double (nullable = true)
#  |    |    |-- decnr: double (nullable = true)
#  |    |    |-- scorr: double (nullable = true)
#  |    |    |-- magzpsci: float (nullable = true)
#  |    |    |-- magzpsciunc: float (nullable = true)
#  |    |    |-- magzpscirms: float (nullable = true)
#  |    |    |-- clrcoeff: float (nullable = true)
#  |    |    |-- clrcounc: float (nullable = true)
#  |    |    |-- rbversion: string (nullable = true)
#  |-- cutoutScience: struct (nullable = true)
#  |    |-- fileName: string (nullable = true)
#  |    |-- stampData: binary (nullable = true)
#  |-- cutoutTemplate: struct (nullable = true)
#  |    |-- fileName: string (nullable = true)
#  |    |-- stampData: binary (nullable = true)
#  |-- cutoutDifference: struct (nullable = true)
#  |    |-- fileName: string (nullable = true)
#  |    |-- stampData: binary (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- cdsxmatch: string (nullable = true)
#  |-- rfscore: double (nullable = true)
#  |-- snn_snia_vs_nonia: double (nullable = true)
#  |-- snn_sn_vs_all: double (nullable = true)
#  |-- mulens: struct (nullable = true)
#  |    |-- class_1: string (nullable = true)
#  |    |-- ml_score_1: double (nullable = true)
#  |    |-- class_2: string (nullable = true)
#  |    |-- ml_score_2: double (nullable = true)
#  |-- roid: integer (nullable = true)
#  |-- nalerthist: integer (nullable = true)
#  |-- knscore: double (nullable = true)
#  |-- fink_broker_version: string (nullable = true)
#  |-- fink_science_version: string (nullable = true)
#  |-- tracklet: string (nullable = true)

# %% [markdown]
# ## Calling the science module
#
# First, you need to concatenate historical + current measurements for the quantities of interest. Here, we only need `magpsf`. Hence we create a new column to the DataFrame called `cmagpsf` (for _concatenated_ `magpsf`):

# %%
# Required alert columns
what = ['magpsf', 'jd', 'sigmapsf', 'fid']

# Use for creating temp name
prefix = 'c'
what_prefix = [prefix + i for i in what]

# Concatenate historical + current measurements
for colname in what:
    df = concat_col(df, colname, prefix=prefix)

what_prefix
# Out:
# ['cmagpsf', 'cjd', 'csigmapsf', 'cfid']

# %%
import light_curve as lc
import numpy as np
import pandas as pd
from fink_science.snad.utilities import fix_nans

# %%
def extract_row(frame, index=0, dtype='float64'):
    return np.array(frame[index][0], dtype=dtype)


def npsave(*args, **kwargs):
    args = [*args]
    args[0] = f"samples/{args[0]}"
    if not args[0].endswith('.npy'):
        args[0] += '.npy'
    return np.save(*args, **kwargs)


def npload(*args, **kwargs):
    args = [*args]
    args[0] = f"samples/{args[0]}"
    if not args[0].endswith('.npy'):
        args[0] += '.npy'
    args[0] = open(args[0], 'rb')
    return np.load(*args, **kwargs)

# %%
import os


def create_sample(n=0):
    cmagpsf = extract_row(df.select('cmagpsf').take(n+1), n)
    cjd = extract_row(df.select('cjd').take(n+1), n)
    csigmapsf = extract_row(df.select('csigmapsf').take(n+1), n)

    if not os.path.exists(f'samples/{n}'):
        os.mkdir(f'samples/{n}')

    npsave(f"{n}/cmagpsf", cmagpsf)
    npsave(f"{n}/cjd", cjd)
    npsave(f"{n}/csigmapsf", csigmapsf)

    return cmagpsf, cjd, csigmapsf


def load_sample(n=0):
    cmagpsf = npload(f"{n}/cmagpsf")
    cjd = npload(f"{n}/cjd")
    csigmapsf = npload(f"{n}/csigmapsf")

    return cmagpsf, cjd, csigmapsf

# %%
create_sample(0)
create_sample(1)
create_sample(2)
create_sample(3)
create_sample(4)
create_sample(5)

print(os.listdir("samples"))
# Out:
# 22/01/24 00:16:36 INFO FileSourceStrategy: Pruning directories with:
# 22/01/24 00:16:36 INFO FileSourceStrategy: Post-Scan Filters:
# 22/01/24 00:16:36 INFO FileSourceStrategy: Output Data Schema: struct<candidate: struct<jd: double, fid: int, pid: bigint, diffmaglim: float, pdiffimfilename: string ... 101 more fields>, prv_candidates: array<struct<jd:double,fid:int,pid:bigint,diffmaglim:float,pdiffimfilename:string,programpi:string,programid:int,candid:bigint,isdiffpos:string,tblid:bigint,nid:int,rcid:int,field:int,xpos:float,ypos:float,ra:double,dec:double,magpsf:float,sigmapsf:float,chipsf:float,magap:float,sigmagap:float,distnr:float,magnr:float,... 33 more fields>>>
# 22/01/24 00:16:36 INFO FileSourceScanExec: Pushed Filters:
# 22/01/24 00:16:36 INFO MemoryStore: Block broadcast_1 stored as values in memory (estimated size 367.9 KB, free 365.9 MB)
# 22/01/24 00:16:36 INFO MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 33.7 KB, free 365.9 MB)
# 22/01/24 00:16:36 INFO BlockManagerInfo: Added broadcast_1_piece0 in memory on 192.168.0.111:62599 (size: 33.7 KB, free: 366.3 MB)
# 22/01/24 00:16:36 INFO SparkContext: Created broadcast 1 from take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:5
# 22/01/24 00:16:36 INFO FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 22/01/24 00:16:36 INFO SparkContext: Starting job: take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:5
# 22/01/24 00:16:36 INFO DAGScheduler: Got job 1 (take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:5) with 1 output partitions
# 22/01/24 00:16:36 INFO DAGScheduler: Final stage: ResultStage 1 (take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:5)
# 22/01/24 00:16:36 INFO DAGScheduler: Parents of final stage: List()
# 22/01/24 00:16:36 INFO DAGScheduler: Missing parents: List()
# 22/01/24 00:16:36 INFO DAGScheduler: Submitting ResultStage 1 (MapPartitionsRDD[6] at take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:5), which has no missing parents
# 22/01/24 00:16:36 INFO MemoryStore: Block broadcast_2 stored as values in memory (estimated size 18.3 KB, free 365.9 MB)
# 22/01/24 00:16:36 INFO MemoryStore: Block broadcast_2_piece0 stored as bytes in memory (estimated size 7.2 KB, free 365.9 MB)
# 22/01/24 00:16:36 INFO BlockManagerInfo: Added broadcast_2_piece0 in memory on 192.168.0.111:62599 (size: 7.2 KB, free: 366.3 MB)
# 22/01/24 00:16:36 INFO SparkContext: Created broadcast 2 from broadcast at DAGScheduler.scala:1184
# 22/01/24 00:16:36 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 1 (MapPartitionsRDD[6] at take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:5) (first 15 tasks are for partitions Vector(0))
# 22/01/24 00:16:36 INFO TaskSchedulerImpl: Adding task set 1.0 with 1 tasks
# 22/01/24 00:16:36 INFO TaskSetManager: Starting task 0.0 in stage 1.0 (TID 1, localhost, executor driver, partition 0, PROCESS_LOCAL, 8358 bytes)
# 22/01/24 00:16:36 INFO Executor: Running task 0.0 in stage 1.0 (TID 1)
# 22/01/24 00:16:36 INFO CodeGenerator: Code generated in 321.09368 ms
# 22/01/24 00:16:36 INFO CodeGenerator: Code generated in 24.242631 ms
# 22/01/24 00:16:36 INFO FileScanRDD: Reading File path: file:///Users/igor/Work/snad/fink-science/fink_science/snad/sample.parquet/part-00000-c66c93e0-4980-4dcf-bee1-166ecf780e07-c000.snappy.parquet, range: 0-4194304, partition values: [empty row]
# 22/01/24 00:16:37 INFO ParquetReadSupport: Going to read the following fields from the Parquet file:
#
# Parquet form:
# message spark_schema {
#   optional group candidate {
#     optional double jd;
#     optional int32 fid;
#     optional int64 pid;
#     optional float diffmaglim;
#     optional binary pdiffimfilename (UTF8);
#     optional binary programpi (UTF8);
#     optional int32 programid;
#     optional int64 candid;
#     optional binary isdiffpos (UTF8);
#     optional int64 tblid;
#     optional int32 nid;
#     optional int32 rcid;
#     optional int32 field;
#     optional float xpos;
#     optional float ypos;
#     optional double ra;
#     optional double dec;
#     optional float magpsf;
#     optional float sigmapsf;
#     optional float chipsf;
#     optional float magap;
#     optional float sigmagap;
#     optional float distnr;
#     optional float magnr;
#     optional float sigmagnr;
#     optional float chinr;
#     optional float sharpnr;
#     optional float sky;
#     optional float magdiff;
#     optional float fwhm;
#     optional float classtar;
#     optional float mindtoedge;
#     optional float magfromlim;
#     optional float seeratio;
#     optional float aimage;
#     optional float bimage;
#     optional float aimagerat;
#     optional float bimagerat;
#     optional float elong;
#     optional int32 nneg;
#     optional int32 nbad;
#     optional float rb;
#     optional float ssdistnr;
#     optional float ssmagnr;
#     optional binary ssnamenr (UTF8);
#     optional float sumrat;
#     optional float magapbig;
#     optional float sigmagapbig;
#     optional double ranr;
#     optional double decnr;
#     optional float sgmag1;
#     optional float srmag1;
#     optional float simag1;
#     optional float szmag1;
#     optional float sgscore1;
#     optional float distpsnr1;
#     optional int32 ndethist;
#     optional int32 ncovhist;
#     optional double jdstarthist;
#     optional double jdendhist;
#     optional double scorr;
#     optional int32 tooflag;
#     optional int64 objectidps1;
#     optional int64 objectidps2;
#     optional float sgmag2;
#     optional float srmag2;
#     optional float simag2;
#     optional float szmag2;
#     optional float sgscore2;
#     optional float distpsnr2;
#     optional int64 objectidps3;
#     optional float sgmag3;
#     optional float srmag3;
#     optional float simag3;
#     optional float szmag3;
#     optional float sgscore3;
#     optional float distpsnr3;
#     optional int32 nmtchps;
#     optional int64 rfid;
#     optional double jdstartref;
#     optional double jdendref;
#     optional int32 nframesref;
#     optional binary rbversion (UTF8);
#     optional float dsnrms;
#     optional float ssnrms;
#     optional float dsdiff;
#     optional float magzpsci;
#     optional float magzpsciunc;
#     optional float magzpscirms;
#     optional int32 nmatches;
#     optional float clrcoeff;
#     optional float clrcounc;
#     optional float zpclrcov;
#     optional float zpmed;
#     optional float clrmed;
#     optional float clrrms;
#     optional float neargaia;
#     optional float neargaiabright;
#     optional float maggaia;
#     optional float maggaiabright;
#     optional float exptime;
#     optional float drb;
#     optional binary drbversion (UTF8);
#   }
#   optional group prv_candidates (LIST) {
#     repeated group list {
#       optional group element {
#         optional double jd;
#         optional int32 fid;
#         optional int64 pid;
#         optional float diffmaglim;
#         optional binary pdiffimfilename (UTF8);
#         optional binary programpi (UTF8);
#         optional int32 programid;
#         optional int64 candid;
#         optional binary isdiffpos (UTF8);
#         optional int64 tblid;
#         optional int32 nid;
#         optional int32 rcid;
#         optional int32 field;
#         optional float xpos;
#         optional float ypos;
#         optional double ra;
#         optional double dec;
#         optional float magpsf;
#         optional float sigmapsf;
#         optional float chipsf;
#         optional float magap;
#         optional float sigmagap;
#         optional float distnr;
#         optional float magnr;
#         optional float sigmagnr;
#         optional float chinr;
#         optional float sharpnr;
#         optional float sky;
#         optional float magdiff;
#         optional float fwhm;
#         optional float classtar;
#         optional float mindtoedge;
#         optional float magfromlim;
#         optional float seeratio;
#         optional float aimage;
#         optional float bimage;
#         optional float aimagerat;
#         optional float bimagerat;
#         optional float elong;
#         optional int32 nneg;
#         optional int32 nbad;
#         optional float rb;
#         optional float ssdistnr;
#         optional float ssmagnr;
#         optional binary ssnamenr (UTF8);
#         optional float sumrat;
#         optional float magapbig;
#         optional float sigmagapbig;
#         optional double ranr;
#         optional double decnr;
#         optional double scorr;
#         optional float magzpsci;
#         optional float magzpsciunc;
#         optional float magzpscirms;
#         optional float clrcoeff;
#         optional float clrcounc;
#         optional binary rbversion (UTF8);
#       }
#     }
#   }
# }
#
# Catalyst form:
# StructType(StructField(candidate,StructType(StructField(jd,DoubleType,true), StructField(fid,IntegerType,true), StructField(pid,LongType,true), StructField(diffmaglim,FloatType,true), StructField(pdiffimfilename,StringType,true), StructField(programpi,StringType,true), StructField(programid,IntegerType,true), StructField(candid,LongType,true), StructField(isdiffpos,StringType,true), StructField(tblid,LongType,true), StructField(nid,IntegerType,true), StructField(rcid,IntegerType,true), StructField(field,IntegerType,true), StructField(xpos,FloatType,true), StructField(ypos,FloatType,true), StructField(ra,DoubleType,true), StructField(dec,DoubleType,true), StructField(magpsf,FloatType,true), StructField(sigmapsf,FloatType,true), StructField(chipsf,FloatType,true), StructField(magap,FloatType,true), StructField(sigmagap,FloatType,true), StructField(distnr,FloatType,true), StructField(magnr,FloatType,true), StructField(sigmagnr,FloatType,true), StructField(chinr,FloatType,true), StructField(sharpnr,FloatType,true), StructField(sky,FloatType,true), StructField(magdiff,FloatType,true), StructField(fwhm,FloatType,true), StructField(classtar,FloatType,true), StructField(mindtoedge,FloatType,true), StructField(magfromlim,FloatType,true), StructField(seeratio,FloatType,true), StructField(aimage,FloatType,true), StructField(bimage,FloatType,true), StructField(aimagerat,FloatType,true), StructField(bimagerat,FloatType,true), StructField(elong,FloatType,true), StructField(nneg,IntegerType,true), StructField(nbad,IntegerType,true), StructField(rb,FloatType,true), StructField(ssdistnr,FloatType,true), StructField(ssmagnr,FloatType,true), StructField(ssnamenr,StringType,true), StructField(sumrat,FloatType,true), StructField(magapbig,FloatType,true), StructField(sigmagapbig,FloatType,true), StructField(ranr,DoubleType,true), StructField(decnr,DoubleType,true), StructField(sgmag1,FloatType,true), StructField(srmag1,FloatType,true), StructField(simag1,FloatType,true), StructField(szmag1,FloatType,true), StructField(sgscore1,FloatType,true), StructField(distpsnr1,FloatType,true), StructField(ndethist,IntegerType,true), StructField(ncovhist,IntegerType,true), StructField(jdstarthist,DoubleType,true), StructField(jdendhist,DoubleType,true), StructField(scorr,DoubleType,true), StructField(tooflag,IntegerType,true), StructField(objectidps1,LongType,true), StructField(objectidps2,LongType,true), StructField(sgmag2,FloatType,true), StructField(srmag2,FloatType,true), StructField(simag2,FloatType,true), StructField(szmag2,FloatType,true), StructField(sgscore2,FloatType,true), StructField(distpsnr2,FloatType,true), StructField(objectidps3,LongType,true), StructField(sgmag3,FloatType,true), StructField(srmag3,FloatType,true), StructField(simag3,FloatType,true), StructField(szmag3,FloatType,true), StructField(sgscore3,FloatType,true), StructField(distpsnr3,FloatType,true), StructField(nmtchps,IntegerType,true), StructField(rfid,LongType,true), StructField(jdstartref,DoubleType,true), StructField(jdendref,DoubleType,true), StructField(nframesref,IntegerType,true), StructField(rbversion,StringType,true), StructField(dsnrms,FloatType,true), StructField(ssnrms,FloatType,true), StructField(dsdiff,FloatType,true), StructField(magzpsci,FloatType,true), StructField(magzpsciunc,FloatType,true), StructField(magzpscirms,FloatType,true), StructField(nmatches,IntegerType,true), StructField(clrcoeff,FloatType,true), StructField(clrcounc,FloatType,true), StructField(zpclrcov,FloatType,true), StructField(zpmed,FloatType,true), StructField(clrmed,FloatType,true), StructField(clrrms,FloatType,true), StructField(neargaia,FloatType,true), StructField(neargaiabright,FloatType,true), StructField(maggaia,FloatType,true), StructField(maggaiabright,FloatType,true), StructField(exptime,FloatType,true), StructField(drb,FloatType,true), StructField(drbversion,StringType,true)),true), StructField(prv_candidates,ArrayType(StructType(StructField(jd,DoubleType,true), StructField(fid,Inte ...
#
# 22/01/24 00:16:37 INFO CodeGenerator: Code generated in 77.925734 ms
# 22/01/24 00:16:37 INFO CodeGenerator: Code generated in 45.590643 ms
# 22/01/24 00:16:37 INFO InternalParquetRecordReader: RecordReader initialized will read a total of 100 records.
# 22/01/24 00:16:37 INFO InternalParquetRecordReader: at row 0. reading next block
# 22/01/24 00:16:37 INFO CodecPool: Got brand-new decompressor [.snappy]
# 22/01/24 00:16:37 INFO InternalParquetRecordReader: block read in memory in 65 ms. row count = 100
# 22/01/24 00:16:37 INFO Executor: Finished task 0.0 in stage 1.0 (TID 1). 1454 bytes result sent to driver
# 22/01/24 00:16:37 INFO TaskSetManager: Finished task 0.0 in stage 1.0 (TID 1) in 1475 ms on localhost (executor driver) (1/1)
# 22/01/24 00:16:37 INFO TaskSchedulerImpl: Removed TaskSet 1.0, whose tasks have all completed, from pool
# 22/01/24 00:16:37 INFO DAGScheduler: ResultStage 1 (take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:5) finished in 1,518 s
# 22/01/24 00:16:37 INFO DAGScheduler: Job 1 finished: take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:5, took 1,522521 s
# 22/01/24 00:16:37 INFO FileSourceStrategy: Pruning directories with:
# 22/01/24 00:16:37 INFO FileSourceStrategy: Post-Scan Filters:
# 22/01/24 00:16:37 INFO FileSourceStrategy: Output Data Schema: struct<candidate: struct<jd: double, fid: int, pid: bigint, diffmaglim: float, pdiffimfilename: string ... 101 more fields>, prv_candidates: array<struct<jd:double,fid:int,pid:bigint,diffmaglim:float,pdiffimfilename:string,programpi:string,programid:int,candid:bigint,isdiffpos:string,tblid:bigint,nid:int,rcid:int,field:int,xpos:float,ypos:float,ra:double,dec:double,magpsf:float,sigmapsf:float,chipsf:float,magap:float,sigmagap:float,distnr:float,magnr:float,... 33 more fields>>>
# 22/01/24 00:16:37 INFO FileSourceScanExec: Pushed Filters:
# 22/01/24 00:16:37 INFO MemoryStore: Block broadcast_3 stored as values in memory (estimated size 367.9 KB, free 365.5 MB)
# 22/01/24 00:16:37 INFO MemoryStore: Block broadcast_3_piece0 stored as bytes in memory (estimated size 33.7 KB, free 365.5 MB)
# 22/01/24 00:16:37 INFO BlockManagerInfo: Added broadcast_3_piece0 in memory on 192.168.0.111:62599 (size: 33.7 KB, free: 366.2 MB)
# 22/01/24 00:16:37 INFO SparkContext: Created broadcast 3 from take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:6
# 22/01/24 00:16:37 INFO FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 22/01/24 00:16:37 INFO SparkContext: Starting job: take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:6
# 22/01/24 00:16:37 INFO DAGScheduler: Got job 2 (take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:6) with 1 output partitions
# 22/01/24 00:16:37 INFO DAGScheduler: Final stage: ResultStage 2 (take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:6)
# 22/01/24 00:16:37 INFO DAGScheduler: Parents of final stage: List()
# 22/01/24 00:16:37 INFO DAGScheduler: Missing parents: List()
# 22/01/24 00:16:37 INFO DAGScheduler: Submitting ResultStage 2 (MapPartitionsRDD[11] at take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:6), which has no missing parents
# 22/01/24 00:16:37 INFO MemoryStore: Block broadcast_4 stored as values in memory (estimated size 18.3 KB, free 365.5 MB)
# 22/01/24 00:16:37 INFO MemoryStore: Block broadcast_4_piece0 stored as bytes in memory (estimated size 7.2 KB, free 365.5 MB)
# 22/01/24 00:16:37 INFO BlockManagerInfo: Added broadcast_4_piece0 in memory on 192.168.0.111:62599 (size: 7.2 KB, free: 366.2 MB)
# 22/01/24 00:16:37 INFO SparkContext: Created broadcast 4 from broadcast at DAGScheduler.scala:1184
# 22/01/24 00:16:37 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 2 (MapPartitionsRDD[11] at take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:6) (first 15 tasks are for partitions Vector(0))
# 22/01/24 00:16:37 INFO TaskSchedulerImpl: Adding task set 2.0 with 1 tasks
# 22/01/24 00:16:37 INFO TaskSetManager: Starting task 0.0 in stage 2.0 (TID 2, localhost, executor driver, partition 0, PROCESS_LOCAL, 8358 bytes)
# 22/01/24 00:16:37 INFO Executor: Running task 0.0 in stage 2.0 (TID 2)
# 22/01/24 00:16:37 INFO CodeGenerator: Code generated in 12.232031 ms
# 22/01/24 00:16:37 INFO FileScanRDD: Reading File path: file:///Users/igor/Work/snad/fink-science/fink_science/snad/sample.parquet/part-00000-c66c93e0-4980-4dcf-bee1-166ecf780e07-c000.snappy.parquet, range: 0-4194304, partition values: [empty row]
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 48
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 50
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 32
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 52
# 22/01/24 00:16:37 INFO BlockManagerInfo: Removed broadcast_2_piece0 on 192.168.0.111:62599 in memory (size: 7.2 KB, free: 366.2 MB)
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 42
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 35
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 44
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 33
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 30
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 36
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 38
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 51
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 54
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 46
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 53
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 39
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 45
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 40
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 47
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 37
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 34
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 41
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 43
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 31
# 22/01/24 00:16:37 INFO ContextCleaner: Cleaned accumulator 49
# 22/01/24 00:16:37 INFO ParquetReadSupport: Going to read the following fields from the Parquet file:
#
# Parquet form:
# message spark_schema {
#   optional group candidate {
#     optional double jd;
#     optional int32 fid;
#     optional int64 pid;
#     optional float diffmaglim;
#     optional binary pdiffimfilename (UTF8);
#     optional binary programpi (UTF8);
#     optional int32 programid;
#     optional int64 candid;
#     optional binary isdiffpos (UTF8);
#     optional int64 tblid;
#     optional int32 nid;
#     optional int32 rcid;
#     optional int32 field;
#     optional float xpos;
#     optional float ypos;
#     optional double ra;
#     optional double dec;
#     optional float magpsf;
#     optional float sigmapsf;
#     optional float chipsf;
#     optional float magap;
#     optional float sigmagap;
#     optional float distnr;
#     optional float magnr;
#     optional float sigmagnr;
#     optional float chinr;
#     optional float sharpnr;
#     optional float sky;
#     optional float magdiff;
#     optional float fwhm;
#     optional float classtar;
#     optional float mindtoedge;
#     optional float magfromlim;
#     optional float seeratio;
#     optional float aimage;
#     optional float bimage;
#     optional float aimagerat;
#     optional float bimagerat;
#     optional float elong;
#     optional int32 nneg;
#     optional int32 nbad;
#     optional float rb;
#     optional float ssdistnr;
#     optional float ssmagnr;
#     optional binary ssnamenr (UTF8);
#     optional float sumrat;
#     optional float magapbig;
#     optional float sigmagapbig;
#     optional double ranr;
#     optional double decnr;
#     optional float sgmag1;
#     optional float srmag1;
#     optional float simag1;
#     optional float szmag1;
#     optional float sgscore1;
#     optional float distpsnr1;
#     optional int32 ndethist;
#     optional int32 ncovhist;
#     optional double jdstarthist;
#     optional double jdendhist;
#     optional double scorr;
#     optional int32 tooflag;
#     optional int64 objectidps1;
#     optional int64 objectidps2;
#     optional float sgmag2;
#     optional float srmag2;
#     optional float simag2;
#     optional float szmag2;
#     optional float sgscore2;
#     optional float distpsnr2;
#     optional int64 objectidps3;
#     optional float sgmag3;
#     optional float srmag3;
#     optional float simag3;
#     optional float szmag3;
#     optional float sgscore3;
#     optional float distpsnr3;
#     optional int32 nmtchps;
#     optional int64 rfid;
#     optional double jdstartref;
#     optional double jdendref;
#     optional int32 nframesref;
#     optional binary rbversion (UTF8);
#     optional float dsnrms;
#     optional float ssnrms;
#     optional float dsdiff;
#     optional float magzpsci;
#     optional float magzpsciunc;
#     optional float magzpscirms;
#     optional int32 nmatches;
#     optional float clrcoeff;
#     optional float clrcounc;
#     optional float zpclrcov;
#     optional float zpmed;
#     optional float clrmed;
#     optional float clrrms;
#     optional float neargaia;
#     optional float neargaiabright;
#     optional float maggaia;
#     optional float maggaiabright;
#     optional float exptime;
#     optional float drb;
#     optional binary drbversion (UTF8);
#   }
#   optional group prv_candidates (LIST) {
#     repeated group list {
#       optional group element {
#         optional double jd;
#         optional int32 fid;
#         optional int64 pid;
#         optional float diffmaglim;
#         optional binary pdiffimfilename (UTF8);
#         optional binary programpi (UTF8);
#         optional int32 programid;
#         optional int64 candid;
#         optional binary isdiffpos (UTF8);
#         optional int64 tblid;
#         optional int32 nid;
#         optional int32 rcid;
#         optional int32 field;
#         optional float xpos;
#         optional float ypos;
#         optional double ra;
#         optional double dec;
#         optional float magpsf;
#         optional float sigmapsf;
#         optional float chipsf;
#         optional float magap;
#         optional float sigmagap;
#         optional float distnr;
#         optional float magnr;
#         optional float sigmagnr;
#         optional float chinr;
#         optional float sharpnr;
#         optional float sky;
#         optional float magdiff;
#         optional float fwhm;
#         optional float classtar;
#         optional float mindtoedge;
#         optional float magfromlim;
#         optional float seeratio;
#         optional float aimage;
#         optional float bimage;
#         optional float aimagerat;
#         optional float bimagerat;
#         optional float elong;
#         optional int32 nneg;
#         optional int32 nbad;
#         optional float rb;
#         optional float ssdistnr;
#         optional float ssmagnr;
#         optional binary ssnamenr (UTF8);
#         optional float sumrat;
#         optional float magapbig;
#         optional float sigmagapbig;
#         optional double ranr;
#         optional double decnr;
#         optional double scorr;
#         optional float magzpsci;
#         optional float magzpsciunc;
#         optional float magzpscirms;
#         optional float clrcoeff;
#         optional float clrcounc;
#         optional binary rbversion (UTF8);
#       }
#     }
#   }
# }
#
# Catalyst form:
# StructType(StructField(candidate,StructType(StructField(jd,DoubleType,true), StructField(fid,IntegerType,true), StructField(pid,LongType,true), StructField(diffmaglim,FloatType,true), StructField(pdiffimfilename,StringType,true), StructField(programpi,StringType,true), StructField(programid,IntegerType,true), StructField(candid,LongType,true), StructField(isdiffpos,StringType,true), StructField(tblid,LongType,true), StructField(nid,IntegerType,true), StructField(rcid,IntegerType,true), StructField(field,IntegerType,true), StructField(xpos,FloatType,true), StructField(ypos,FloatType,true), StructField(ra,DoubleType,true), StructField(dec,DoubleType,true), StructField(magpsf,FloatType,true), StructField(sigmapsf,FloatType,true), StructField(chipsf,FloatType,true), StructField(magap,FloatType,true), StructField(sigmagap,FloatType,true), StructField(distnr,FloatType,true), StructField(magnr,FloatType,true), StructField(sigmagnr,FloatType,true), StructField(chinr,FloatType,true), StructField(sharpnr,FloatType,true), StructField(sky,FloatType,true), StructField(magdiff,FloatType,true), StructField(fwhm,FloatType,true), StructField(classtar,FloatType,true), StructField(mindtoedge,FloatType,true), StructField(magfromlim,FloatType,true), StructField(seeratio,FloatType,true), StructField(aimage,FloatType,true), StructField(bimage,FloatType,true), StructField(aimagerat,FloatType,true), StructField(bimagerat,FloatType,true), StructField(elong,FloatType,true), StructField(nneg,IntegerType,true), StructField(nbad,IntegerType,true), StructField(rb,FloatType,true), StructField(ssdistnr,FloatType,true), StructField(ssmagnr,FloatType,true), StructField(ssnamenr,StringType,true), StructField(sumrat,FloatType,true), StructField(magapbig,FloatType,true), StructField(sigmagapbig,FloatType,true), StructField(ranr,DoubleType,true), StructField(decnr,DoubleType,true), StructField(sgmag1,FloatType,true), StructField(srmag1,FloatType,true), StructField(simag1,FloatType,true), StructField(szmag1,FloatType,true), StructField(sgscore1,FloatType,true), StructField(distpsnr1,FloatType,true), StructField(ndethist,IntegerType,true), StructField(ncovhist,IntegerType,true), StructField(jdstarthist,DoubleType,true), StructField(jdendhist,DoubleType,true), StructField(scorr,DoubleType,true), StructField(tooflag,IntegerType,true), StructField(objectidps1,LongType,true), StructField(objectidps2,LongType,true), StructField(sgmag2,FloatType,true), StructField(srmag2,FloatType,true), StructField(simag2,FloatType,true), StructField(szmag2,FloatType,true), StructField(sgscore2,FloatType,true), StructField(distpsnr2,FloatType,true), StructField(objectidps3,LongType,true), StructField(sgmag3,FloatType,true), StructField(srmag3,FloatType,true), StructField(simag3,FloatType,true), StructField(szmag3,FloatType,true), StructField(sgscore3,FloatType,true), StructField(distpsnr3,FloatType,true), StructField(nmtchps,IntegerType,true), StructField(rfid,LongType,true), StructField(jdstartref,DoubleType,true), StructField(jdendref,DoubleType,true), StructField(nframesref,IntegerType,true), StructField(rbversion,StringType,true), StructField(dsnrms,FloatType,true), StructField(ssnrms,FloatType,true), StructField(dsdiff,FloatType,true), StructField(magzpsci,FloatType,true), StructField(magzpsciunc,FloatType,true), StructField(magzpscirms,FloatType,true), StructField(nmatches,IntegerType,true), StructField(clrcoeff,FloatType,true), StructField(clrcounc,FloatType,true), StructField(zpclrcov,FloatType,true), StructField(zpmed,FloatType,true), StructField(clrmed,FloatType,true), StructField(clrrms,FloatType,true), StructField(neargaia,FloatType,true), StructField(neargaiabright,FloatType,true), StructField(maggaia,FloatType,true), StructField(maggaiabright,FloatType,true), StructField(exptime,FloatType,true), StructField(drb,FloatType,true), StructField(drbversion,StringType,true)),true), StructField(prv_candidates,ArrayType(StructType(StructField(jd,DoubleType,true), StructField(fid,Inte ...
#
# 22/01/24 00:16:38 INFO InternalParquetRecordReader: RecordReader initialized will read a total of 100 records.
# 22/01/24 00:16:38 INFO InternalParquetRecordReader: at row 0. reading next block
# 22/01/24 00:16:38 INFO InternalParquetRecordReader: block read in memory in 4 ms. row count = 100
# 22/01/24 00:16:38 INFO Executor: Finished task 0.0 in stage 2.0 (TID 2). 1521 bytes result sent to driver
# 22/01/24 00:16:38 INFO TaskSetManager: Finished task 0.0 in stage 2.0 (TID 2) in 97 ms on localhost (executor driver) (1/1)
# 22/01/24 00:16:38 INFO TaskSchedulerImpl: Removed TaskSet 2.0, whose tasks have all completed, from pool
# 22/01/24 00:16:38 INFO DAGScheduler: ResultStage 2 (take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:6) finished in 0,106 s
# 22/01/24 00:16:38 INFO DAGScheduler: Job 2 finished: take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:6, took 0,107953 s
# 22/01/24 00:16:38 INFO FileSourceStrategy: Pruning directories with:
# 22/01/24 00:16:38 INFO FileSourceStrategy: Post-Scan Filters:
# 22/01/24 00:16:38 INFO FileSourceStrategy: Output Data Schema: struct<candidate: struct<jd: double, fid: int, pid: bigint, diffmaglim: float, pdiffimfilename: string ... 101 more fields>, prv_candidates: array<struct<jd:double,fid:int,pid:bigint,diffmaglim:float,pdiffimfilename:string,programpi:string,programid:int,candid:bigint,isdiffpos:string,tblid:bigint,nid:int,rcid:int,field:int,xpos:float,ypos:float,ra:double,dec:double,magpsf:float,sigmapsf:float,chipsf:float,magap:float,sigmagap:float,distnr:float,magnr:float,... 33 more fields>>>
# 22/01/24 00:16:38 INFO FileSourceScanExec: Pushed Filters:
# 22/01/24 00:16:38 INFO MemoryStore: Block broadcast_5 stored as values in memory (estimated size 367.9 KB, free 365.1 MB)
# 22/01/24 00:16:38 INFO MemoryStore: Block broadcast_5_piece0 stored as bytes in memory (estimated size 33.7 KB, free 365.1 MB)
# 22/01/24 00:16:38 INFO BlockManagerInfo: Added broadcast_5_piece0 in memory on 192.168.0.111:62599 (size: 33.7 KB, free: 366.2 MB)
# 22/01/24 00:16:38 INFO SparkContext: Created broadcast 5 from take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:7
# 22/01/24 00:16:38 INFO FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 22/01/24 00:16:38 INFO SparkContext: Starting job: take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:7
# 22/01/24 00:16:38 INFO DAGScheduler: Got job 3 (take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:7) with 1 output partitions
# 22/01/24 00:16:38 INFO DAGScheduler: Final stage: ResultStage 3 (take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:7)
# 22/01/24 00:16:38 INFO DAGScheduler: Parents of final stage: List()
# 22/01/24 00:16:38 INFO DAGScheduler: Missing parents: List()
# 22/01/24 00:16:38 INFO DAGScheduler: Submitting ResultStage 3 (MapPartitionsRDD[16] at take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:7), which has no missing parents
# 22/01/24 00:16:38 INFO MemoryStore: Block broadcast_6 stored as values in memory (estimated size 18.4 KB, free 365.1 MB)
# 22/01/24 00:16:38 INFO MemoryStore: Block broadcast_6_piece0 stored as bytes in memory (estimated size 7.2 KB, free 365.1 MB)
# 22/01/24 00:16:38 INFO BlockManagerInfo: Added broadcast_6_piece0 in memory on 192.168.0.111:62599 (size: 7.2 KB, free: 366.2 MB)
# 22/01/24 00:16:38 INFO SparkContext: Created broadcast 6 from broadcast at DAGScheduler.scala:1184
# 22/01/24 00:16:38 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 3 (MapPartitionsRDD[16] at take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:7) (first 15 tasks are for partitions Vector(0))
# 22/01/24 00:16:38 INFO TaskSchedulerImpl: Adding task set 3.0 with 1 tasks
# 22/01/24 00:16:38 INFO TaskSetManager: Starting task 0.0 in stage 3.0 (TID 3, localhost, executor driver, partition 0, PROCESS_LOCAL, 8358 bytes)
# 22/01/24 00:16:38 INFO Executor: Running task 0.0 in stage 3.0 (TID 3)
# 22/01/24 00:16:38 INFO CodeGenerator: Code generated in 21.901014 ms
# 22/01/24 00:16:38 INFO FileScanRDD: Reading File path: file:///Users/igor/Work/snad/fink-science/fink_science/snad/sample.parquet/part-00000-c66c93e0-4980-4dcf-bee1-166ecf780e07-c000.snappy.parquet, range: 0-4194304, partition values: [empty row]
# 22/01/24 00:16:38 INFO ParquetReadSupport: Going to read the following fields from the Parquet file:
#
# Parquet form:
# message spark_schema {
#   optional group candidate {
#     optional double jd;
#     optional int32 fid;
#     optional int64 pid;
#     optional float diffmaglim;
#     optional binary pdiffimfilename (UTF8);
#     optional binary programpi (UTF8);
#     optional int32 programid;
#     optional int64 candid;
#     optional binary isdiffpos (UTF8);
#     optional int64 tblid;
#     optional int32 nid;
#     optional int32 rcid;
#     optional int32 field;
#     optional float xpos;
#     optional float ypos;
#     optional double ra;
#     optional double dec;
#     optional float magpsf;
#     optional float sigmapsf;
#     optional float chipsf;
#     optional float magap;
#     optional float sigmagap;
#     optional float distnr;
#     optional float magnr;
#     optional float sigmagnr;
#     optional float chinr;
#     optional float sharpnr;
#     optional float sky;
#     optional float magdiff;
#     optional float fwhm;
#     optional float classtar;
#     optional float mindtoedge;
#     optional float magfromlim;
#     optional float seeratio;
#     optional float aimage;
#     optional float bimage;
#     optional float aimagerat;
#     optional float bimagerat;
#     optional float elong;
#     optional int32 nneg;
#     optional int32 nbad;
#     optional float rb;
#     optional float ssdistnr;
#     optional float ssmagnr;
#     optional binary ssnamenr (UTF8);
#     optional float sumrat;
#     optional float magapbig;
#     optional float sigmagapbig;
#     optional double ranr;
#     optional double decnr;
#     optional float sgmag1;
#     optional float srmag1;
#     optional float simag1;
#     optional float szmag1;
#     optional float sgscore1;
#     optional float distpsnr1;
#     optional int32 ndethist;
#     optional int32 ncovhist;
#     optional double jdstarthist;
#     optional double jdendhist;
#     optional double scorr;
#     optional int32 tooflag;
#     optional int64 objectidps1;
#     optional int64 objectidps2;
#     optional float sgmag2;
#     optional float srmag2;
#     optional float simag2;
#     optional float szmag2;
#     optional float sgscore2;
#     optional float distpsnr2;
#     optional int64 objectidps3;
#     optional float sgmag3;
#     optional float srmag3;
#     optional float simag3;
#     optional float szmag3;
#     optional float sgscore3;
#     optional float distpsnr3;
#     optional int32 nmtchps;
#     optional int64 rfid;
#     optional double jdstartref;
#     optional double jdendref;
#     optional int32 nframesref;
#     optional binary rbversion (UTF8);
#     optional float dsnrms;
#     optional float ssnrms;
#     optional float dsdiff;
#     optional float magzpsci;
#     optional float magzpsciunc;
#     optional float magzpscirms;
#     optional int32 nmatches;
#     optional float clrcoeff;
#     optional float clrcounc;
#     optional float zpclrcov;
#     optional float zpmed;
#     optional float clrmed;
#     optional float clrrms;
#     optional float neargaia;
#     optional float neargaiabright;
#     optional float maggaia;
#     optional float maggaiabright;
#     optional float exptime;
#     optional float drb;
#     optional binary drbversion (UTF8);
#   }
#   optional group prv_candidates (LIST) {
#     repeated group list {
#       optional group element {
#         optional double jd;
#         optional int32 fid;
#         optional int64 pid;
#         optional float diffmaglim;
#         optional binary pdiffimfilename (UTF8);
#         optional binary programpi (UTF8);
#         optional int32 programid;
#         optional int64 candid;
#         optional binary isdiffpos (UTF8);
#         optional int64 tblid;
#         optional int32 nid;
#         optional int32 rcid;
#         optional int32 field;
#         optional float xpos;
#         optional float ypos;
#         optional double ra;
#         optional double dec;
#         optional float magpsf;
#         optional float sigmapsf;
#         optional float chipsf;
#         optional float magap;
#         optional float sigmagap;
#         optional float distnr;
#         optional float magnr;
#         optional float sigmagnr;
#         optional float chinr;
#         optional float sharpnr;
#         optional float sky;
#         optional float magdiff;
#         optional float fwhm;
#         optional float classtar;
#         optional float mindtoedge;
#         optional float magfromlim;
#         optional float seeratio;
#         optional float aimage;
#         optional float bimage;
#         optional float aimagerat;
#         optional float bimagerat;
#         optional float elong;
#         optional int32 nneg;
#         optional int32 nbad;
#         optional float rb;
#         optional float ssdistnr;
#         optional float ssmagnr;
#         optional binary ssnamenr (UTF8);
#         optional float sumrat;
#         optional float magapbig;
#         optional float sigmagapbig;
#         optional double ranr;
#         optional double decnr;
#         optional double scorr;
#         optional float magzpsci;
#         optional float magzpsciunc;
#         optional float magzpscirms;
#         optional float clrcoeff;
#         optional float clrcounc;
#         optional binary rbversion (UTF8);
#       }
#     }
#   }
# }
#
# Catalyst form:
# StructType(StructField(candidate,StructType(StructField(jd,DoubleType,true), StructField(fid,IntegerType,true), StructField(pid,LongType,true), StructField(diffmaglim,FloatType,true), StructField(pdiffimfilename,StringType,true), StructField(programpi,StringType,true), StructField(programid,IntegerType,true), StructField(candid,LongType,true), StructField(isdiffpos,StringType,true), StructField(tblid,LongType,true), StructField(nid,IntegerType,true), StructField(rcid,IntegerType,true), StructField(field,IntegerType,true), StructField(xpos,FloatType,true), StructField(ypos,FloatType,true), StructField(ra,DoubleType,true), StructField(dec,DoubleType,true), StructField(magpsf,FloatType,true), StructField(sigmapsf,FloatType,true), StructField(chipsf,FloatType,true), StructField(magap,FloatType,true), StructField(sigmagap,FloatType,true), StructField(distnr,FloatType,true), StructField(magnr,FloatType,true), StructField(sigmagnr,FloatType,true), StructField(chinr,FloatType,true), StructField(sharpnr,FloatType,true), StructField(sky,FloatType,true), StructField(magdiff,FloatType,true), StructField(fwhm,FloatType,true), StructField(classtar,FloatType,true), StructField(mindtoedge,FloatType,true), StructField(magfromlim,FloatType,true), StructField(seeratio,FloatType,true), StructField(aimage,FloatType,true), StructField(bimage,FloatType,true), StructField(aimagerat,FloatType,true), StructField(bimagerat,FloatType,true), StructField(elong,FloatType,true), StructField(nneg,IntegerType,true), StructField(nbad,IntegerType,true), StructField(rb,FloatType,true), StructField(ssdistnr,FloatType,true), StructField(ssmagnr,FloatType,true), StructField(ssnamenr,StringType,true), StructField(sumrat,FloatType,true), StructField(magapbig,FloatType,true), StructField(sigmagapbig,FloatType,true), StructField(ranr,DoubleType,true), StructField(decnr,DoubleType,true), StructField(sgmag1,FloatType,true), StructField(srmag1,FloatType,true), StructField(simag1,FloatType,true), StructField(szmag1,FloatType,true), StructField(sgscore1,FloatType,true), StructField(distpsnr1,FloatType,true), StructField(ndethist,IntegerType,true), StructField(ncovhist,IntegerType,true), StructField(jdstarthist,DoubleType,true), StructField(jdendhist,DoubleType,true), StructField(scorr,DoubleType,true), StructField(tooflag,IntegerType,true), StructField(objectidps1,LongType,true), StructField(objectidps2,LongType,true), StructField(sgmag2,FloatType,true), StructField(srmag2,FloatType,true), StructField(simag2,FloatType,true), StructField(szmag2,FloatType,true), StructField(sgscore2,FloatType,true), StructField(distpsnr2,FloatType,true), StructField(objectidps3,LongType,true), StructField(sgmag3,FloatType,true), StructField(srmag3,FloatType,true), StructField(simag3,FloatType,true), StructField(szmag3,FloatType,true), StructField(sgscore3,FloatType,true), StructField(distpsnr3,FloatType,true), StructField(nmtchps,IntegerType,true), StructField(rfid,LongType,true), StructField(jdstartref,DoubleType,true), StructField(jdendref,DoubleType,true), StructField(nframesref,IntegerType,true), StructField(rbversion,StringType,true), StructField(dsnrms,FloatType,true), StructField(ssnrms,FloatType,true), StructField(dsdiff,FloatType,true), StructField(magzpsci,FloatType,true), StructField(magzpsciunc,FloatType,true), StructField(magzpscirms,FloatType,true), StructField(nmatches,IntegerType,true), StructField(clrcoeff,FloatType,true), StructField(clrcounc,FloatType,true), StructField(zpclrcov,FloatType,true), StructField(zpmed,FloatType,true), StructField(clrmed,FloatType,true), StructField(clrrms,FloatType,true), StructField(neargaia,FloatType,true), StructField(neargaiabright,FloatType,true), StructField(maggaia,FloatType,true), StructField(maggaiabright,FloatType,true), StructField(exptime,FloatType,true), StructField(drb,FloatType,true), StructField(drbversion,StringType,true)),true), StructField(prv_candidates,ArrayType(StructType(StructField(jd,DoubleType,true), StructField(fid,Inte ...
#
# 22/01/24 00:16:38 INFO InternalParquetRecordReader: RecordReader initialized will read a total of 100 records.
# 22/01/24 00:16:38 INFO InternalParquetRecordReader: at row 0. reading next block
# 22/01/24 00:16:38 INFO InternalParquetRecordReader: block read in memory in 8 ms. row count = 100
# 22/01/24 00:16:38 INFO Executor: Finished task 0.0 in stage 3.0 (TID 3). 1413 bytes result sent to driver
# 22/01/24 00:16:38 INFO TaskSetManager: Finished task 0.0 in stage 3.0 (TID 3) in 139 ms on localhost (executor driver) (1/1)
# 22/01/24 00:16:38 INFO TaskSchedulerImpl: Removed TaskSet 3.0, whose tasks have all completed, from pool
# 22/01/24 00:16:38 INFO DAGScheduler: ResultStage 3 (take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:7) finished in 0,156 s
# 22/01/24 00:16:38 INFO DAGScheduler: Job 3 finished: take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:7, took 0,159886 s
# 22/01/24 00:16:38 INFO FileSourceStrategy: Pruning directories with:
# 22/01/24 00:16:38 INFO FileSourceStrategy: Post-Scan Filters:
# 22/01/24 00:16:38 INFO FileSourceStrategy: Output Data Schema: struct<candidate: struct<jd: double, fid: int, pid: bigint, diffmaglim: float, pdiffimfilename: string ... 101 more fields>, prv_candidates: array<struct<jd:double,fid:int,pid:bigint,diffmaglim:float,pdiffimfilename:string,programpi:string,programid:int,candid:bigint,isdiffpos:string,tblid:bigint,nid:int,rcid:int,field:int,xpos:float,ypos:float,ra:double,dec:double,magpsf:float,sigmapsf:float,chipsf:float,magap:float,sigmagap:float,distnr:float,magnr:float,... 33 more fields>>>
# 22/01/24 00:16:38 INFO FileSourceScanExec: Pushed Filters:
# 22/01/24 00:16:38 INFO MemoryStore: Block broadcast_7 stored as values in memory (estimated size 367.9 KB, free 364.7 MB)
# 22/01/24 00:16:38 INFO MemoryStore: Block broadcast_7_piece0 stored as bytes in memory (estimated size 33.7 KB, free 364.7 MB)
# 22/01/24 00:16:38 INFO BlockManagerInfo: Added broadcast_7_piece0 in memory on 192.168.0.111:62599 (size: 33.7 KB, free: 366.2 MB)
# 22/01/24 00:16:38 INFO SparkContext: Created broadcast 7 from take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:5
# 22/01/24 00:16:38 INFO FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 22/01/24 00:16:38 INFO SparkContext: Starting job: take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:5
# 22/01/24 00:16:38 INFO DAGScheduler: Got job 4 (take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:5) with 1 output partitions
# 22/01/24 00:16:38 INFO DAGScheduler: Final stage: ResultStage 4 (take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:5)
# 22/01/24 00:16:38 INFO DAGScheduler: Parents of final stage: List()
# 22/01/24 00:16:38 INFO DAGScheduler: Missing parents: List()
# 22/01/24 00:16:38 INFO DAGScheduler: Submitting ResultStage 4 (MapPartitionsRDD[21] at take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:5), which has no missing parents
# 22/01/24 00:16:38 INFO MemoryStore: Block broadcast_8 stored as values in memory (estimated size 18.3 KB, free 364.7 MB)
# 22/01/24 00:16:38 INFO MemoryStore: Block broadcast_8_piece0 stored as bytes in memory (estimated size 7.2 KB, free 364.7 MB)
# 22/01/24 00:16:38 INFO BlockManagerInfo: Added broadcast_8_piece0 in memory on 192.168.0.111:62599 (size: 7.2 KB, free: 366.1 MB)
# 22/01/24 00:16:38 INFO SparkContext: Created broadcast 8 from broadcast at DAGScheduler.scala:1184
# 22/01/24 00:16:38 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 4 (MapPartitionsRDD[21] at take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:5) (first 15 tasks are for partitions Vector(0))
# 22/01/24 00:16:38 INFO TaskSchedulerImpl: Adding task set 4.0 with 1 tasks
# 22/01/24 00:16:38 INFO TaskSetManager: Starting task 0.0 in stage 4.0 (TID 4, localhost, executor driver, partition 0, PROCESS_LOCAL, 8358 bytes)
# 22/01/24 00:16:38 INFO Executor: Running task 0.0 in stage 4.0 (TID 4)
# 22/01/24 00:16:38 INFO FileScanRDD: Reading File path: file:///Users/igor/Work/snad/fink-science/fink_science/snad/sample.parquet/part-00000-c66c93e0-4980-4dcf-bee1-166ecf780e07-c000.snappy.parquet, range: 0-4194304, partition values: [empty row]
# 22/01/24 00:16:38 INFO ParquetReadSupport: Going to read the following fields from the Parquet file:
#
# Parquet form:
# message spark_schema {
#   optional group candidate {
#     optional double jd;
#     optional int32 fid;
#     optional int64 pid;
#     optional float diffmaglim;
#     optional binary pdiffimfilename (UTF8);
#     optional binary programpi (UTF8);
#     optional int32 programid;
#     optional int64 candid;
#     optional binary isdiffpos (UTF8);
#     optional int64 tblid;
#     optional int32 nid;
#     optional int32 rcid;
#     optional int32 field;
#     optional float xpos;
#     optional float ypos;
#     optional double ra;
#     optional double dec;
#     optional float magpsf;
#     optional float sigmapsf;
#     optional float chipsf;
#     optional float magap;
#     optional float sigmagap;
#     optional float distnr;
#     optional float magnr;
#     optional float sigmagnr;
#     optional float chinr;
#     optional float sharpnr;
#     optional float sky;
#     optional float magdiff;
#     optional float fwhm;
#     optional float classtar;
#     optional float mindtoedge;
#     optional float magfromlim;
#     optional float seeratio;
#     optional float aimage;
#     optional float bimage;
#     optional float aimagerat;
#     optional float bimagerat;
#     optional float elong;
#     optional int32 nneg;
#     optional int32 nbad;
#     optional float rb;
#     optional float ssdistnr;
#     optional float ssmagnr;
#     optional binary ssnamenr (UTF8);
#     optional float sumrat;
#     optional float magapbig;
#     optional float sigmagapbig;
#     optional double ranr;
#     optional double decnr;
#     optional float sgmag1;
#     optional float srmag1;
#     optional float simag1;
#     optional float szmag1;
#     optional float sgscore1;
#     optional float distpsnr1;
#     optional int32 ndethist;
# ...
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 419
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 456
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 430
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 445
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 442
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 455
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 487
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 448
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 416
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 425
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 472
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 468
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 411
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 467
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 418
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 478
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 431
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 471
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 412
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 453
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 454
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 443
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 422
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 439
# 22/01/24 00:16:40 INFO BlockManagerInfo: Removed broadcast_28_piece0 on 192.168.0.111:62599 in memory (size: 7.2 KB, free: 365.8 MB)
# 22/01/24 00:16:40 INFO Executor: Finished task 0.0 in stage 17.0 (TID 17). 2293 bytes result sent to driver
# 22/01/24 00:16:40 INFO TaskSetManager: Finished task 0.0 in stage 17.0 (TID 17) in 50 ms on localhost (executor driver) (1/1)
# 22/01/24 00:16:40 INFO TaskSchedulerImpl: Removed TaskSet 17.0, whose tasks have all completed, from pool
# 22/01/24 00:16:40 INFO DAGScheduler: ResultStage 17 (take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:6) finished in 0,055 s
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 441
# 22/01/24 00:16:40 INFO ContextCleaner: Cleaned accumulator 480
# 22/01/24 00:16:40 INFO DAGScheduler: Job 17 finished: take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:6, took 0,056913 s
# 22/01/24 00:16:40 INFO FileSourceStrategy: Pruning directories with:
# 22/01/24 00:16:40 INFO FileSourceStrategy: Post-Scan Filters:
# 22/01/24 00:16:40 INFO FileSourceStrategy: Output Data Schema: struct<candidate: struct<jd: double, fid: int, pid: bigint, diffmaglim: float, pdiffimfilename: string ... 101 more fields>, prv_candidates: array<struct<jd:double,fid:int,pid:bigint,diffmaglim:float,pdiffimfilename:string,programpi:string,programid:int,candid:bigint,isdiffpos:string,tblid:bigint,nid:int,rcid:int,field:int,xpos:float,ypos:float,ra:double,dec:double,magpsf:float,sigmapsf:float,chipsf:float,magap:float,sigmagap:float,distnr:float,magnr:float,... 33 more fields>>>
# 22/01/24 00:16:40 INFO FileSourceScanExec: Pushed Filters:
# 22/01/24 00:16:40 INFO MemoryStore: Block broadcast_35 stored as values in memory (estimated size 367.9 KB, free 359.6 MB)
# 22/01/24 00:16:40 INFO MemoryStore: Block broadcast_35_piece0 stored as bytes in memory (estimated size 33.7 KB, free 359.6 MB)
# 22/01/24 00:16:40 INFO BlockManagerInfo: Added broadcast_35_piece0 in memory on 192.168.0.111:62599 (size: 33.7 KB, free: 365.7 MB)
# 22/01/24 00:16:40 INFO SparkContext: Created broadcast 35 from take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:7
# 22/01/24 00:16:40 INFO FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 22/01/24 00:16:40 INFO SparkContext: Starting job: take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:7
# 22/01/24 00:16:40 INFO DAGScheduler: Got job 18 (take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:7) with 1 output partitions
# 22/01/24 00:16:40 INFO DAGScheduler: Final stage: ResultStage 18 (take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:7)
# 22/01/24 00:16:40 INFO DAGScheduler: Parents of final stage: List()
# 22/01/24 00:16:40 INFO DAGScheduler: Missing parents: List()
# 22/01/24 00:16:40 INFO DAGScheduler: Submitting ResultStage 18 (MapPartitionsRDD[91] at take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:7), which has no missing parents
# 22/01/24 00:16:40 INFO MemoryStore: Block broadcast_36 stored as values in memory (estimated size 18.4 KB, free 359.5 MB)
# 22/01/24 00:16:40 INFO MemoryStore: Block broadcast_36_piece0 stored as bytes in memory (estimated size 7.2 KB, free 359.5 MB)
# 22/01/24 00:16:40 INFO BlockManagerInfo: Added broadcast_36_piece0 in memory on 192.168.0.111:62599 (size: 7.2 KB, free: 365.7 MB)
# 22/01/24 00:16:40 INFO SparkContext: Created broadcast 36 from broadcast at DAGScheduler.scala:1184
# 22/01/24 00:16:40 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 18 (MapPartitionsRDD[91] at take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:7) (first 15 tasks are for partitions Vector(0))
# 22/01/24 00:16:40 INFO TaskSchedulerImpl: Adding task set 18.0 with 1 tasks
# 22/01/24 00:16:40 INFO TaskSetManager: Starting task 0.0 in stage 18.0 (TID 18, localhost, executor driver, partition 0, PROCESS_LOCAL, 8358 bytes)
# 22/01/24 00:16:40 INFO Executor: Running task 0.0 in stage 18.0 (TID 18)
# 22/01/24 00:16:40 INFO FileScanRDD: Reading File path: file:///Users/igor/Work/snad/fink-science/fink_science/snad/sample.parquet/part-00000-c66c93e0-4980-4dcf-bee1-166ecf780e07-c000.snappy.parquet, range: 0-4194304, partition values: [empty row]
# 22/01/24 00:16:40 INFO ParquetReadSupport: Going to read the following fields from the Parquet file:
#
# Parquet form:
# message spark_schema {
#   optional group candidate {
#     optional double jd;
#     optional int32 fid;
#     optional int64 pid;
#     optional float diffmaglim;
#     optional binary pdiffimfilename (UTF8);
#     optional binary programpi (UTF8);
#     optional int32 programid;
#     optional int64 candid;
#     optional binary isdiffpos (UTF8);
#     optional int64 tblid;
#     optional int32 nid;
#     optional int32 rcid;
#     optional int32 field;
#     optional float xpos;
#     optional float ypos;
#     optional double ra;
#     optional double dec;
#     optional float magpsf;
#     optional float sigmapsf;
#     optional float chipsf;
#     optional float magap;
#     optional float sigmagap;
#     optional float distnr;
#     optional float magnr;
#     optional float sigmagnr;
#     optional float chinr;
#     optional float sharpnr;
#     optional float sky;
#     optional float magdiff;
#     optional float fwhm;
#     optional float classtar;
#     optional float mindtoedge;
#     optional float magfromlim;
#     optional float seeratio;
#     optional float aimage;
#     optional float bimage;
#     optional float aimagerat;
#     optional float bimagerat;
#     optional float elong;
#     optional int32 nneg;
#     optional int32 nbad;
#     optional float rb;
#     optional float ssdistnr;
#     optional float ssmagnr;
#     optional binary ssnamenr (UTF8);
#     optional float sumrat;
#     optional float magapbig;
#     optional float sigmagapbig;
#     optional double ranr;
#     optional double decnr;
#     optional float sgmag1;
#     optional float srmag1;
#     optional float simag1;
#     optional float szmag1;
#     optional float sgscore1;
#     optional float distpsnr1;
#     optional int32 ndethist;
#     optional int32 ncovhist;
#     optional double jdstarthist;
#     optional double jdendhist;
#     optional double scorr;
#     optional int32 tooflag;
#     optional int64 objectidps1;
#     optional int64 objectidps2;
#     optional float sgmag2;
#     optional float srmag2;
#     optional float simag2;
#     optional float szmag2;
#     optional float sgscore2;
#     optional float distpsnr2;
#     optional int64 objectidps3;
#     optional float sgmag3;
#     optional float srmag3;
#     optional float simag3;
#     optional float szmag3;
#     optional float sgscore3;
#     optional float distpsnr3;
#     optional int32 nmtchps;
#     optional int64 rfid;
#     optional double jdstartref;
#     optional double jdendref;
#     optional int32 nframesref;
#     optional binary rbversion (UTF8);
#     optional float dsnrms;
#     optional float ssnrms;
#     optional float dsdiff;
#     optional float magzpsci;
#     optional float magzpsciunc;
#     optional float magzpscirms;
#     optional int32 nmatches;
#     optional float clrcoeff;
#     optional float clrcounc;
#     optional float zpclrcov;
#     optional float zpmed;
#     optional float clrmed;
#     optional float clrrms;
#     optional float neargaia;
#     optional float neargaiabright;
#     optional float maggaia;
#     optional float maggaiabright;
#     optional float exptime;
#     optional float drb;
#     optional binary drbversion (UTF8);
#   }
#   optional group prv_candidates (LIST) {
#     repeated group list {
#       optional group element {
#         optional double jd;
#         optional int32 fid;
#         optional int64 pid;
#         optional float diffmaglim;
#         optional binary pdiffimfilename (UTF8);
#         optional binary programpi (UTF8);
#         optional int32 programid;
#         optional int64 candid;
#         optional binary isdiffpos (UTF8);
#         optional int64 tblid;
#         optional int32 nid;
#         optional int32 rcid;
#         optional int32 field;
#         optional float xpos;
#         optional float ypos;
#         optional double ra;
#         optional double dec;
#         optional float magpsf;
#         optional float sigmapsf;
#         optional float chipsf;
#         optional float magap;
#         optional float sigmagap;
#         optional float distnr;
#         optional float magnr;
#         optional float sigmagnr;
#         optional float chinr;
#         optional float sharpnr;
#         optional float sky;
#         optional float magdiff;
#         optional float fwhm;
#         optional float classtar;
#         optional float mindtoedge;
#         optional float magfromlim;
#         optional float seeratio;
#         optional float aimage;
#         optional float bimage;
#         optional float aimagerat;
#         optional float bimagerat;
#         optional float elong;
#         optional int32 nneg;
#         optional int32 nbad;
#         optional float rb;
#         optional float ssdistnr;
#         optional float ssmagnr;
#         optional binary ssnamenr (UTF8);
#         optional float sumrat;
#         optional float magapbig;
#         optional float sigmagapbig;
#         optional double ranr;
#         optional double decnr;
#         optional double scorr;
#         optional float magzpsci;
#         optional float magzpsciunc;
#         optional float magzpscirms;
#         optional float clrcoeff;
#         optional float clrcounc;
#         optional binary rbversion (UTF8);
#       }
#     }
#   }
# }
#
# Catalyst form:
# StructType(StructField(candidate,StructType(StructField(jd,DoubleType,true), StructField(fid,IntegerType,true), StructField(pid,LongType,true), StructField(diffmaglim,FloatType,true), StructField(pdiffimfilename,StringType,true), StructField(programpi,StringType,true), StructField(programid,IntegerType,true), StructField(candid,LongType,true), StructField(isdiffpos,StringType,true), StructField(tblid,LongType,true), StructField(nid,IntegerType,true), StructField(rcid,IntegerType,true), StructField(field,IntegerType,true), StructField(xpos,FloatType,true), StructField(ypos,FloatType,true), StructField(ra,DoubleType,true), StructField(dec,DoubleType,true), StructField(magpsf,FloatType,true), StructField(sigmapsf,FloatType,true), StructField(chipsf,FloatType,true), StructField(magap,FloatType,true), StructField(sigmagap,FloatType,true), StructField(distnr,FloatType,true), StructField(magnr,FloatType,true), StructField(sigmagnr,FloatType,true), StructField(chinr,FloatType,true), StructField(sharpnr,FloatType,true), StructField(sky,FloatType,true), StructField(magdiff,FloatType,true), StructField(fwhm,FloatType,true), StructField(classtar,FloatType,true), StructField(mindtoedge,FloatType,true), StructField(magfromlim,FloatType,true), StructField(seeratio,FloatType,true), StructField(aimage,FloatType,true), StructField(bimage,FloatType,true), StructField(aimagerat,FloatType,true), StructField(bimagerat,FloatType,true), StructField(elong,FloatType,true), StructField(nneg,IntegerType,true), StructField(nbad,IntegerType,true), StructField(rb,FloatType,true), StructField(ssdistnr,FloatType,true), StructField(ssmagnr,FloatType,true), StructField(ssnamenr,StringType,true), StructField(sumrat,FloatType,true), StructField(magapbig,FloatType,true), StructField(sigmagapbig,FloatType,true), StructField(ranr,DoubleType,true), StructField(decnr,DoubleType,true), StructField(sgmag1,FloatType,true), StructField(srmag1,FloatType,true), StructField(simag1,FloatType,true), StructField(szmag1,FloatType,true), StructField(sgscore1,FloatType,true), StructField(distpsnr1,FloatType,true), StructField(ndethist,IntegerType,true), StructField(ncovhist,IntegerType,true), StructField(jdstarthist,DoubleType,true), StructField(jdendhist,DoubleType,true), StructField(scorr,DoubleType,true), StructField(tooflag,IntegerType,true), StructField(objectidps1,LongType,true), StructField(objectidps2,LongType,true), StructField(sgmag2,FloatType,true), StructField(srmag2,FloatType,true), StructField(simag2,FloatType,true), StructField(szmag2,FloatType,true), StructField(sgscore2,FloatType,true), StructField(distpsnr2,FloatType,true), StructField(objectidps3,LongType,true), StructField(sgmag3,FloatType,true), StructField(srmag3,FloatType,true), StructField(simag3,FloatType,true), StructField(szmag3,FloatType,true), StructField(sgscore3,FloatType,true), StructField(distpsnr3,FloatType,true), StructField(nmtchps,IntegerType,true), StructField(rfid,LongType,true), StructField(jdstartref,DoubleType,true), StructField(jdendref,DoubleType,true), StructField(nframesref,IntegerType,true), StructField(rbversion,StringType,true), StructField(dsnrms,FloatType,true), StructField(ssnrms,FloatType,true), StructField(dsdiff,FloatType,true), StructField(magzpsci,FloatType,true), StructField(magzpsciunc,FloatType,true), StructField(magzpscirms,FloatType,true), StructField(nmatches,IntegerType,true), StructField(clrcoeff,FloatType,true), StructField(clrcounc,FloatType,true), StructField(zpclrcov,FloatType,true), StructField(zpmed,FloatType,true), StructField(clrmed,FloatType,true), StructField(clrrms,FloatType,true), StructField(neargaia,FloatType,true), StructField(neargaiabright,FloatType,true), StructField(maggaia,FloatType,true), StructField(maggaiabright,FloatType,true), StructField(exptime,FloatType,true), StructField(drb,FloatType,true), StructField(drbversion,StringType,true)),true), StructField(prv_candidates,ArrayType(StructType(StructField(jd,DoubleType,true), StructField(fid,Inte ...
#
# 22/01/24 00:16:40 INFO InternalParquetRecordReader: RecordReader initialized will read a total of 100 records.
# 22/01/24 00:16:40 INFO InternalParquetRecordReader: at row 0. reading next block
# 22/01/24 00:16:40 INFO InternalParquetRecordReader: block read in memory in 1 ms. row count = 100
# 22/01/24 00:16:40 INFO Executor: Finished task 0.0 in stage 18.0 (TID 18). 1788 bytes result sent to driver
# 22/01/24 00:16:40 INFO TaskSetManager: Finished task 0.0 in stage 18.0 (TID 18) in 34 ms on localhost (executor driver) (1/1)
# 22/01/24 00:16:40 INFO TaskSchedulerImpl: Removed TaskSet 18.0, whose tasks have all completed, from pool
# 22/01/24 00:16:40 INFO DAGScheduler: ResultStage 18 (take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:7) finished in 0,040 s
# 22/01/24 00:16:40 INFO DAGScheduler: Job 18 finished: take at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/2478389446.py:7, took 0,041542 s

# %%
def extract(magpsf, jd, sigmapsf):
    fix_nans(cmagpsf)
    fix_nans(csigmapsf)

    extractor = lc.Extractor(
        lc.Amplitude(),
        lc.BeyondNStd(nstd=1),
        lc.LinearFit(),
        lc.Mean(),
        lc.Median(),
        lc.StandardDeviation(),
        lc.Cusum(),
        lc.ExcessVariance(),
        lc.MeanVariance(),
        lc.Kurtosis(),
        lc.MaximumSlope(),
        lc.Skew(),
        lc.WeightedMean(),
        lc.Eta(),
        lc.AndersonDarlingNormal(),
        lc.ReducedChi2(),
        lc.InterPercentileRange(quantile=0.1),
        #lc.MagnitudePercentageRatio(),
        lc.MedianBufferRangePercentage(quantile=0.1),
        lc.PercentDifferenceMagnitudePercentile(quantile=0.1),
        lc.MedianAbsoluteDeviation(),
        lc.PercentAmplitude(),
        lc.EtaE(),
        lc.LinearTrend(),
        lc.StetsonK(),
        lc.WeightedMean(),
        #lc.Bins(),
        #lc.OtsuSplit(),
    )

    result = extractor(cjd, cmagpsf, csigmapsf)
    print('\n'.join("{} = {:.2f}".format(name, value) for name, value in zip(extractor.names, result)))  # DEBUG
    return result

# %%
cmagpsf, cjd, csigmapsf = load_sample(1)

describe = lambda v: print(type(v), len(v), np.mean(v), np.std(v))

assert cmagpsf.shape == cjd.shape == csigmapsf.shape, 'Mismatched shapes'

describe(cmagpsf)
describe(cjd)
describe(csigmapsf)

# separator for result
print("\n--------------\n")

res = extract(cmagpsf, cjd, csigmapsf)
# Out:
# <class 'numpy.ndarray'> 34 nan nan
# <class 'numpy.ndarray'> 34 2459526.124098582 7.321780152225849
# <class 'numpy.ndarray'> 34 nan nan
#
# --------------
#
# amplitude = 1.52
# beyond_1_std = 0.47
# linear_fit_slope = -0.07
# linear_fit_slope_sigma = 0.00
# linear_fit_reduced_chi2 = 98.81
# mean = 18.47
# median = 18.22
# standard_deviation = 0.97
# cusum = 0.32
# excess_variance = 0.00
# mean_variance = 0.05
# kurtosis = -1.26
# maximum_slope = 123.08
# skew = -0.17
# weighted_mean = 17.55
# eta = 1.32
# anderson_darling_normal = 1.25
# chi2 = 112.38
# inter_percentile_range_10 = 2.52
# median_buffer_range_percentage_10 = 0.00
# percent_difference_magnitude_percentile_10 = 0.14
# median_absolute_deviation = 0.85
# percent_amplitude = 1.56
# eta_e = 591.79
# linear_trend = -0.07
# linear_trend_sigma = 0.02
# linear_trend_noise = 0.86
# stetson_K = 0.84
# weighted_mean = 17.55

# %%
# %load_ext autoreload
import importlib
import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
# %aimport processor
importlib.reload(processor)

lc_columns = processor.column_names  # import as
extract_features_snad = processor.extract_features_snad  # direct import

snad_base_col = 'lc_features'
snad_args = ['cmagpsf', 'cjd', 'csigmapsf', 'cfid']
df = df.withColumn(snad_base_col, extract_features_snad(*snad_args))
for index, name in enumerate(lc_columns):
    df = df.withColumn(name, df[snad_base_col][index])
df = df.drop(snad_base_col)

output_file_name = "output.csv"
try:
    os.remove(output_file_name)
except OSError:
    pass

selected_data = df.select(['objectId', *lc_columns])
selected_data.toPandas().to_csv(output_file_name, encoding='utf-8', index=False)
# Out:
# 22/01/24 01:28:17 INFO FileSourceStrategy: Pruning directories with:
# 22/01/24 01:28:17 INFO FileSourceStrategy: Post-Scan Filters:
# 22/01/24 01:28:17 INFO FileSourceStrategy: Output Data Schema: struct<objectId: string, candidate: struct<jd: double, fid: int, pid: bigint, diffmaglim: float, pdiffimfilename: string ... 101 more fields>, prv_candidates: array<struct<jd:double,fid:int,pid:bigint,diffmaglim:float,pdiffimfilename:string,programpi:string,programid:int,candid:bigint,isdiffpos:string,tblid:bigint,nid:int,rcid:int,field:int,xpos:float,ypos:float,ra:double,dec:double,magpsf:float,sigmapsf:float,chipsf:float,magap:float,sigmagap:float,distnr:float,magnr:float,... 33 more fields>> ... 1 more fields>
# 22/01/24 01:28:17 INFO FileSourceScanExec: Pushed Filters:
# 22/01/24 01:28:17 INFO MemoryStore: Block broadcast_51 stored as values in memory (estimated size 368.1 KB, free 364.8 MB)
# 22/01/24 01:28:17 INFO MemoryStore: Block broadcast_51_piece0 stored as bytes in memory (estimated size 33.6 KB, free 364.7 MB)
# 22/01/24 01:28:17 INFO BlockManagerInfo: Added broadcast_51_piece0 in memory on 192.168.0.111:62599 (size: 33.6 KB, free: 366.2 MB)
# 22/01/24 01:28:17 INFO SparkContext: Created broadcast 51 from toPandas at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/3795175238.py:22
# 22/01/24 01:28:17 INFO FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 22/01/24 01:28:17 INFO SparkContext: Starting job: toPandas at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/3795175238.py:22
# 22/01/24 01:28:17 INFO DAGScheduler: Got job 26 (toPandas at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/3795175238.py:22) with 6 output partitions
# 22/01/24 01:28:17 INFO DAGScheduler: Final stage: ResultStage 26 (toPandas at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/3795175238.py:22)
# 22/01/24 01:28:17 INFO DAGScheduler: Parents of final stage: List()
# 22/01/24 01:28:17 INFO DAGScheduler: Missing parents: List()
# 22/01/24 01:28:17 INFO DAGScheduler: Submitting ResultStage 26 (MapPartitionsRDD[147] at toPandas at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/3795175238.py:22), which has no missing parents
# 22/01/24 01:28:17 INFO MemoryStore: Block broadcast_52 stored as values in memory (estimated size 32.0 KB, free 364.7 MB)
# 22/01/24 01:28:17 INFO MemoryStore: Block broadcast_52_piece0 stored as bytes in memory (estimated size 13.0 KB, free 364.7 MB)
# 22/01/24 01:28:17 INFO BlockManagerInfo: Added broadcast_52_piece0 in memory on 192.168.0.111:62599 (size: 13.0 KB, free: 366.2 MB)
# 22/01/24 01:28:17 INFO SparkContext: Created broadcast 52 from broadcast at DAGScheduler.scala:1184
# 22/01/24 01:28:17 INFO DAGScheduler: Submitting 6 missing tasks from ResultStage 26 (MapPartitionsRDD[147] at toPandas at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/3795175238.py:22) (first 15 tasks are for partitions Vector(0, 1, 2, 3, 4, 5))
# 22/01/24 01:28:17 INFO TaskSchedulerImpl: Adding task set 26.0 with 6 tasks
# 22/01/24 01:28:17 INFO TaskSetManager: Starting task 0.0 in stage 26.0 (TID 61, localhost, executor driver, partition 0, PROCESS_LOCAL, 8358 bytes)
# 22/01/24 01:28:17 INFO TaskSetManager: Starting task 1.0 in stage 26.0 (TID 62, localhost, executor driver, partition 1, PROCESS_LOCAL, 8358 bytes)
# 22/01/24 01:28:17 INFO TaskSetManager: Starting task 2.0 in stage 26.0 (TID 63, localhost, executor driver, partition 2, PROCESS_LOCAL, 8358 bytes)
# 22/01/24 01:28:17 INFO TaskSetManager: Starting task 3.0 in stage 26.0 (TID 64, localhost, executor driver, partition 3, PROCESS_LOCAL, 8358 bytes)
# 22/01/24 01:28:17 INFO TaskSetManager: Starting task 4.0 in stage 26.0 (TID 65, localhost, executor driver, partition 4, PROCESS_LOCAL, 8358 bytes)
# 22/01/24 01:28:17 INFO TaskSetManager: Starting task 5.0 in stage 26.0 (TID 66, localhost, executor driver, partition 5, PROCESS_LOCAL, 8358 bytes)
# 22/01/24 01:28:17 INFO Executor: Running task 0.0 in stage 26.0 (TID 61)
# 22/01/24 01:28:17 INFO Executor: Running task 1.0 in stage 26.0 (TID 62)
# 22/01/24 01:28:17 INFO Executor: Running task 2.0 in stage 26.0 (TID 63)
# 22/01/24 01:28:17 INFO Executor: Running task 3.0 in stage 26.0 (TID 64)
# 22/01/24 01:28:17 INFO Executor: Running task 4.0 in stage 26.0 (TID 65)
# 22/01/24 01:28:17 INFO Executor: Running task 5.0 in stage 26.0 (TID 66)
# 22/01/24 01:28:17 INFO FileScanRDD: Reading File path: file:///Users/igor/Work/snad/fink-science/fink_science/snad/sample.parquet/part-00000-c66c93e0-4980-4dcf-bee1-166ecf780e07-c000.snappy.parquet, range: 0-4194304, partition values: [empty row]
# 22/01/24 01:28:17 INFO FileScanRDD: Reading File path: file:///Users/igor/Work/snad/fink-science/fink_science/snad/sample.parquet/part-00003-c66c93e0-4980-4dcf-bee1-166ecf780e07-c000.snappy.parquet, range: 0-2509970, partition values: [empty row]
# 22/01/24 01:28:17 INFO ParquetReadSupport: Going to read the following fields from the Parquet file:
#
# Parquet form:
# message spark_schema {
#   optional binary objectId (UTF8);
#   optional group candidate {
#     optional double jd;
#     optional int32 fid;
#     optional int64 pid;
#     optional float diffmaglim;
#     optional binary pdiffimfilename (UTF8);
#     optional binary programpi (UTF8);
#     optional int32 programid;
#     optional int64 candid;
#     optional binary isdiffpos (UTF8);
#     optional int64 tblid;
#     optional int32 nid;
#     optional int32 rcid;
#     optional int32 field;
#     optional float xpos;
#     optional float ypos;
#     optional double ra;
#     optional double dec;
#     optional float magpsf;
#     optional float sigmapsf;
#     optional float chipsf;
#     optional float magap;
#     optional float sigmagap;
#     optional float distnr;
#     optional float magnr;
#     optional float sigmagnr;
#     optional float chinr;
#     optional float sharpnr;
#     optional float sky;
#     optional float magdiff;
#     optional float fwhm;
#     optional float classtar;
#     optional float mindtoedge;
#     optional float magfromlim;
#     optional float seeratio;
#     optional float aimage;
#     optional float bimage;
#     optional float aimagerat;
#     optional float bimagerat;
#     optional float elong;
#     optional int32 nneg;
#     optional int32 nbad;
#     optional float rb;
#     optional float ssdistnr;
#     optional float ssmagnr;
#     optional binary ssnamenr (UTF8);
#     optional float sumrat;
#     optional float magapbig;
#     optional float sigmagapbig;
#     optional double ranr;
#     optional double decnr;
#     optional float sgmag1;
#     optional float srmag1;
#     optional float simag1;
#     optional float szmag1;
#     optional float sgscore1;
#     optional float distpsnr1;
#     optional int32 ndethist;
#     optional int32 ncovhist;
#     optional double jdstarthist;
#     optional double jdendhist;
#     optional double scorr;
#     optional int32 tooflag;
#     optional int64 objectidps1;
#     optional int64 objectidps2;
#     optional float sgmag2;
#     optional float srmag2;
#     optional float simag2;
#     optional float szmag2;
#     optional float sgscore2;
#     optional float distpsnr2;
#     optional int64 objectidps3;
#     optional float sgmag3;
#     optional float srmag3;
#     optional float simag3;
#     optional float szmag3;
#     optional float sgscore3;
#     optional float distpsnr3;
#     optional int32 nmtchps;
#     optional int64 rfid;
#     optional double jdstartref;
#     optional double jdendref;
#     optional int32 nframesref;
#     optional binary rbversion (UTF8);
#     optional float dsnrms;
#     optional float ssnrms;
#     optional float dsdiff;
#     optional float magzpsci;
#     optional float magzpsciunc;
#     optional float magzpscirms;
#     optional int32 nmatches;
#     optional float clrcoeff;
#     optional float clrcounc;
#     optional float zpclrcov;
#     optional float zpmed;
#     optional float clrmed;
#     optional float clrrms;
#     optional float neargaia;
#     optional float neargaiabright;
#     optional float maggaia;
#     optional float maggaiabright;
#     optional float exptime;
#     optional float drb;
#     optional binary drbversion (UTF8);
#   }
#   optional group prv_candidates (LIST) {
#     repeated group list {
#       optional group element {
#         optional double jd;
#         optional int32 fid;
#         optional int64 pid;
#         optional float diffmaglim;
#         optional binary pdiffimfilename (UTF8);
#         optional binary programpi (UTF8);
#         optional int32 programid;
#         optional int64 candid;
#         optional binary isdiffpos (UTF8);
#         optional int64 tblid;
#         optional int32 nid;
#         optional int32 rcid;
#         optional int32 field;
#         optional float xpos;
#         optional float ypos;
#         optional double ra;
#         optional double dec;
#         optional float magpsf;
#         optional float sigmapsf;
#         optional float chipsf;
#         optional float magap;
#         optional float sigmagap;
#         optional float distnr;
#         optional float magnr;
#         optional float sigmagnr;
#         optional float chinr;
#         optional float sharpnr;
#         optional float sky;
#         optional float magdiff;
#         optional float fwhm;
#         optional float classtar;
#         optional float mindtoedge;
#         optional float magfromlim;
#         optional float seeratio;
#         optional float aimage;
#         optional float bimage;
#         optional float aimagerat;
#         optional float bimagerat;
#         optional float elong;
#         optional int32 nneg;
#         optional int32 nbad;
#         optional float rb;
#         optional float ssdistnr;
#         optional float ssmagnr;
#         optional binary ssnamenr (UTF8);
#         optional float sumrat;
#         optional float magapbig;
#         optional float sigmagapbig;
#         optional double ranr;
#         optional double decnr;
#         optional double scorr;
#         optional float magzpsci;
#         optional float magzpsciunc;
#         optional float magzpscirms;
#         optional float clrcoeff;
#         optional float clrcounc;
#         optional binary rbversion (UTF8);
#       }
#     }
#   }
# }
#
# Catalyst form:
# StructType(StructField(objectId,StringType,true), StructField(candidate,StructType(StructField(jd,DoubleType,true), StructField(fid,IntegerType,true), StructField(pid,LongType,true), StructField(diffmaglim,FloatType,true), StructField(pdiffimfilename,StringType,true), StructField(programpi,StringType,true), StructField(programid,IntegerType,true), StructField(candid,LongType,true), StructField(isdiffpos,StringType,true), StructField(tblid,LongType,true), StructField(nid,IntegerType,true), StructField(rcid,IntegerType,true), StructField(field,IntegerType,true), StructField(xpos,FloatType,true), StructField(ypos,FloatType,true), StructField(ra,DoubleType,true), StructField(dec,DoubleType,true), StructField(magpsf,FloatType,true), StructField(sigmapsf,FloatType,true), StructField(chipsf,FloatType,true), StructField(magap,FloatType,true), StructField(sigmagap,FloatType,true), StructField(distnr,FloatType,true), StructField(magnr,FloatType,true), StructField(sigmagnr,FloatType,true), StructField(chinr,FloatType,true), StructField(sharpnr,FloatType,true), StructField(sky,FloatType,true), StructField(magdiff,FloatType,true), StructField(fwhm,FloatType,true), StructField(classtar,FloatType,true), StructField(mindtoedge,FloatType,true), StructField(magfromlim,FloatType,true), StructField(seeratio,FloatType,true), StructField(aimage,FloatType,true), StructField(bimage,FloatType,true), StructField(aimagerat,FloatType,true), StructField(bimagerat,FloatType,true), StructField(elong,FloatType,true), StructField(nneg,IntegerType,true), StructField(nbad,IntegerType,true), StructField(rb,FloatType,true), StructField(ssdistnr,FloatType,true), StructField(ssmagnr,FloatType,true), StructField(ssnamenr,StringType,true), StructField(sumrat,FloatType,true), StructField(magapbig,FloatType,true), StructField(sigmagapbig,FloatType,true), StructField(ranr,DoubleType,true), StructField(decnr,DoubleType,true), StructField(sgmag1,FloatType,true), StructField(srmag1,FloatType,true), StructField(simag1,FloatType,true), StructField(szmag1,FloatType,true), StructField(sgscore1,FloatType,true), StructField(distpsnr1,FloatType,true), StructField(ndethist,IntegerType,true), StructField(ncovhist,IntegerType,true), StructField(jdstarthist,DoubleType,true), StructField(jdendhist,DoubleType,true), StructField(scorr,DoubleType,true), StructField(tooflag,IntegerType,true), StructField(objectidps1,LongType,true), StructField(objectidps2,LongType,true), StructField(sgmag2,FloatType,true), StructField(srmag2,FloatType,true), StructField(simag2,FloatType,true), StructField(szmag2,FloatType,true), StructField(sgscore2,FloatType,true), StructField(distpsnr2,FloatType,true), StructField(objectidps3,LongType,true), StructField(sgmag3,FloatType,true), StructField(srmag3,FloatType,true), StructField(simag3,FloatType,true), StructField(szmag3,FloatType,true), StructField(sgscore3,FloatType,true), StructField(distpsnr3,FloatType,true), StructField(nmtchps,IntegerType,true), StructField(rfid,LongType,true), StructField(jdstartref,DoubleType,true), StructField(jdendref,DoubleType,true), StructField(nframesref,IntegerType,true), StructField(rbversion,StringType,true), StructField(dsnrms,FloatType,true), StructField(ssnrms,FloatType,true), StructField(dsdiff,FloatType,true), StructField(magzpsci,FloatType,true), StructField(magzpsciunc,FloatType,true), StructField(magzpscirms,FloatType,true), StructField(nmatches,IntegerType,true), StructField(clrcoeff,FloatType,true), StructField(clrcounc,FloatType,true), StructField(zpclrcov,FloatType,true), StructField(zpmed,FloatType,true), StructField(clrmed,FloatType,true), StructField(clrrms,FloatType,true), StructField(neargaia,FloatType,true), StructField(neargaiabright,FloatType,true), StructField(maggaia,FloatType,true), StructField(maggaiabright,FloatType,true), StructField(exptime,FloatType,true), StructField(drb,FloatType,true), StructField(drbversion,StringType,true)),true), StructField(prv_candidates,ArrayType(StructType(StructField(jd ...
#
# 22/01/24 01:28:17 INFO FileScanRDD: Reading File path: file:///Users/igor/Work/snad/fink-science/fink_science/snad/sample.parquet/part-00000-c66c93e0-4980-4dcf-bee1-166ecf780e07-c000.snappy.parquet, range: 4194304-4387354, partition values: [empty row]
# 22/01/24 01:28:17 INFO ParquetReadSupport: Going to read the following fields from the Parquet file:
#
# Parquet form:
# message spark_schema {
#   optional binary objectId (UTF8);
#   optional group candidate {
#     optional double jd;
#     optional int32 fid;
#     optional int64 pid;
#     optional float diffmaglim;
#     optional binary pdiffimfilename (UTF8);
#     optional binary programpi (UTF8);
#     optional int32 programid;
#     optional int64 candid;
#     optional binary isdiffpos (UTF8);
#     optional int64 tblid;
#     optional int32 nid;
#     optional int32 rcid;
#     optional int32 field;
#     optional float xpos;
#     optional float ypos;
#     optional double ra;
#     optional double dec;
#     optional float magpsf;
#     optional float sigmapsf;
#     optional float chipsf;
#     optional float magap;
#     optional float sigmagap;
#     optional float distnr;
#     optional float magnr;
#     optional float sigmagnr;
#     optional float chinr;
#     optional float sharpnr;
#     optional float sky;
#     optional float magdiff;
#     optional float fwhm;
#     optional float classtar;
#     optional float mindtoedge;
#     optional float magfromlim;
#     optional float seeratio;
#     optional float aimage;
#     optional float bimage;
#     optional float aimagerat;
#     optional float bimagerat;
#     optional float elong;
#     optional int32 nneg;
#     optional int32 nbad;
#     optional float rb;
#     optional float ssdistnr;
#     optional float ssmagnr;
#     optional binary ssnamenr (UTF8);
#     optional float sumrat;
#     optional float magapbig;
#     optional float sigmagapbig;
#     optional double ranr;
#     optional double decnr;
#     optional float sgmag1;
#     optional float srmag1;
#     optional float simag1;
#     optional float szmag1;
#     optional float sgscore1;
#     optional float distpsnr1;
#     optional int32 ndethist;
#     optional int32 ncovhist;
#     optional double jdstarthist;
#     optional double jdendhist;
#     optional double scorr;
#     optional int32 tooflag;
#     optional int64 objectidps1;
#     optional int64 objectidps2;
#     optional float sgmag2;
#     optional float srmag2;
#     optional float simag2;
#     optional float szmag2;
#     optional float sgscore2;
#     optional float distpsnr2;
#     optional int64 objectidps3;
#     optional float sgmag3;
#     optional float srmag3;
#     optional float simag3;
#     optional float szmag3;
#     optional float sgscore3;
#     optional float distpsnr3;
#     optional int32 nmtchps;
#     optional int64 rfid;
#     optional double jdstartref;
#     optional double jdendref;
#     optional int32 nframesref;
#     optional binary rbversion (UTF8);
#     optional float dsnrms;
#     optional float ssnrms;
#     optional float dsdiff;
#     optional float magzpsci;
#     optional float magzpsciunc;
#     optional float magzpscirms;
#     optional int32 nmatches;
#     optional float clrcoeff;
#     optional float clrcounc;
#     optional float zpclrcov;
#     optional float zpmed;
#     optional float clrmed;
#     optional float clrrms;
#     optional float neargaia;
#     optional float neargaiabright;
#     optional float maggaia;
#     optional float maggaiabright;
#     optional float exptime;
#     optional float drb;
#     optional binary drbversion (UTF8);
#   }
#   optional group prv_candidates (LIST) {
#     repeated group list {
#       optional group element {
#         optional double jd;
#         optional int32 fid;
#         optional int64 pid;
#         optional float diffmaglim;
#         optional binary pdiffimfilename (UTF8);
#         optional binary programpi (UTF8);
#         optional int32 programid;
#         optional int64 candid;
#         optional binary isdiffpos (UTF8);
#         optional int64 tblid;
#         optional int32 nid;
#         optional int32 rcid;
#         optional int32 field;
#         optional float xpos;
#         optional float ypos;
#         optional double ra;
#         optional double dec;
#         optional float magpsf;
#         optional float sigmapsf;
#         optional float chipsf;
#         optional float magap;
#         optional float sigmagap;
#         optional float distnr;
#         optional float magnr;
#         optional float sigmagnr;
#         optional float chinr;
#         optional float sharpnr;
#         optional float sky;
#         optional float magdiff;
#         optional float fwhm;
#         optional float classtar;
#         optional float mindtoedge;
#         optional float magfromlim;
#         optional float seeratio;
#         optional float aimage;
#         optional float bimage;
#         optional float aimagerat;
#         optional float bimagerat;
#         optional float elong;
#         optional int32 nneg;
#         optional int32 nbad;
#         optional float rb;
#         optional float ssdistnr;
#         optional float ssmagnr;
#         optional binary ssnamenr (UTF8);
#         optional float sumrat;
#         optional float magapbig;
#         optional float sigmagapbig;
#         optional double ranr;
#         optional double decnr;
#         optional double scorr;
#         optional float magzpsci;
#         optional float magzpsciunc;
#         optional float magzpscirms;
#         optional float clrcoeff;
#         optional float clrcounc;
#         optional binary rbversion (UTF8);
#       }
#     }
#   }
# }
#
# Catalyst form:
# StructType(StructField(objectId,StringType,true), StructField(candidate,StructType(StructField(jd,DoubleType,true), StructField(fid,IntegerType,true), StructField(pid,LongType,true), StructField(diffmaglim,FloatType,true), StructField(pdiffimfilename,StringType,true), StructField(programpi,StringType,true), StructField(programid,IntegerType,true), StructField(candid,LongType,true), StructField(isdiffpos,StringType,true), StructField(tblid,LongType,true), StructField(nid,IntegerType,true), StructField(rcid,IntegerType,true), StructField(field,IntegerType,true), StructField(xpos,FloatType,true), StructField(ypos,FloatType,true), StructField(ra,DoubleType,true), StructField(dec,DoubleType,true), StructField(magpsf,FloatType,true), StructField(sigmapsf,FloatType,true), StructField(chipsf,FloatType,true), StructField(magap,FloatType,true), StructField(sigmagap,FloatType,true), StructField(distnr,FloatType,true), StructField(magnr,FloatType,true), StructField(sigmagnr,FloatType,true), StructField(chinr,FloatType,true), StructField(sharpnr,FloatType,true), StructField(sky,FloatType,true), StructField(magdiff,FloatType,true), StructField(fwhm,FloatType,true), StructField(classtar,FloatType,true), StructField(mindtoedge,FloatType,true), StructField(magfromlim,FloatType,true), StructField(seeratio,FloatType,true), StructField(aimage,FloatType,true), StructField(bimage,FloatType,true), StructField(aimagerat,FloatType,true), StructField(bimagerat,FloatType,true), StructField(elong,FloatType,true), StructField(nneg,IntegerType,true), StructField(nbad,IntegerType,true), StructField(rb,FloatType,true), StructField(ssdistnr,FloatType,true), StructField(ssmagnr,FloatType,true), StructField(ssnamenr,StringType,true), StructField(sumrat,FloatType,true), StructField(magapbig,FloatType,true), StructField(sigmagapbig,FloatType,true), StructField(ranr,DoubleType,true), StructField(decnr,DoubleType,true), StructField(sgmag1,FloatType,true), StructField(srmag1,FloatType,true), StructField(simag1,FloatType,true), StructField(szmag1,FloatType,true), StructField(sgscore1,FloatType,true), StructField(distpsnr1,FloatType,true), StructField(ndethist,IntegerType,true), StructField(ncovhist,IntegerType,true), StructField(jdstarthist,DoubleType,true), StructField(jdendhist,DoubleType,true), StructField(scorr,DoubleType,true), StructField(tooflag,IntegerType,true), StructField(objectidps1,LongType,true), StructField(objectidps2,LongType,true), StructField(sgmag2,FloatType,true), StructField(srmag2,FloatType,true), StructField(simag2,FloatType,true), StructField(szmag2,FloatType,true), StructField(sgscore2,FloatType,true), StructField(distpsnr2,FloatType,true), StructField(objectidps3,LongType,true), StructField(sgmag3,FloatType,true), StructField(srmag3,FloatType,true), StructField(simag3,FloatType,true), StructField(szmag3,FloatType,true), StructField(sgscore3,FloatType,true), StructField(distpsnr3,FloatType,true), StructField(nmtchps,IntegerType,true), StructField(rfid,LongType,true), StructField(jdstartref,DoubleType,true), StructField(jdendref,DoubleType,true), StructField(nframesref,IntegerType,true), StructField(rbversion,StringType,true), StructField(dsnrms,FloatType,true), StructField(ssnrms,FloatType,true), StructField(dsdiff,FloatType,true), StructField(magzpsci,FloatType,true), StructField(magzpsciunc,FloatType,true), StructField(magzpscirms,FloatType,true), StructField(nmatches,IntegerType,true), StructField(clrcoeff,FloatType,true), StructField(clrcounc,FloatType,true), StructField(zpclrcov,FloatType,true), StructField(zpmed,FloatType,true), StructField(clrmed,FloatType,true), StructField(clrrms,FloatType,true), StructField(neargaia,FloatType,true), StructField(neargaiabright,FloatType,true), StructField(maggaia,FloatType,true), StructField(maggaiabright,FloatType,true), StructField(exptime,FloatType,true), StructField(drb,FloatType,true), StructField(drbversion,StringType,true)),true), StructField(prv_candidates,ArrayType(StructType(StructField(jd ...
#
# 22/01/24 01:28:17 INFO FileScanRDD: Reading File path: file:///Users/igor/Work/snad/fink-science/fink_science/snad/sample.parquet/part-00002-c66c93e0-4980-4dcf-bee1-166ecf780e07-c000.snappy.parquet, range: 4194304-4226938, partition values: [empty row]
# 22/01/24 01:28:17 INFO ParquetReadSupport: Going to read the following fields from the Parquet file:
#
# Parquet form:
# message spark_schema {
#   optional binary objectId (UTF8);
#   optional group candidate {
#     optional double jd;
#     optional int32 fid;
#     optional int64 pid;
#     optional float diffmaglim;
#     optional binary pdiffimfilename (UTF8);
#     optional binary programpi (UTF8);
#     optional int32 programid;
#     optional int64 candid;
#     optional binary isdiffpos (UTF8);
#     optional int64 tblid;
#     optional int32 nid;
#     optional int32 rcid;
#     optional int32 field;
#     optional float xpos;
#     optional float ypos;
#     optional double ra;
#     optional double dec;
#     optional float magpsf;
#     optional float sigmapsf;
#     optional float chipsf;
#     optional float magap;
#     optional float sigmagap;
#     optional float distnr;
#     optional float magnr;
#     optional float sigmagnr;
#     optional float chinr;
#     optional float sharpnr;
#     optional float sky;
#     optional float magdiff;
#     optional float fwhm;
#     optional float classtar;
#     optional float mindtoedge;
#     optional float magfromlim;
#     optional float seeratio;
#     optional float aimage;
#     optional float bimage;
#     optional float aimagerat;
#     optional float bimagerat;
#     optional float elong;
#     optional int32 nneg;
#     optional int32 nbad;
#     optional float rb;
#     optional float ssdistnr;
#     optional float ssmagnr;
#     optional binary ssnamenr (UTF8);
#     optional float sumrat;
#     optional float magapbig;
#     optional float sigmagapbig;
#     optional double ranr;
#     optional double decnr;
#     optional float sgmag1;
#     optional float srmag1;
#     optional float simag1;
#     optional float szmag1;
#     optional float sgscore1;
#     optional float distpsnr1;
#     optional int32 ndethist;
#     optional int32 ncovhist;
#     optional double jdstarthist;
#     optional double jdendhist;
#     optional double scorr;
#     optional int32 tooflag;
#     optional int64 objectidps1;
#     optional int64 objectidps2;
#     optional float sgmag2;
#     optional float srmag2;
#     optional float simag2;
#     optional float szmag2;
#     optional float sgscore2;
#     optional float distpsnr2;
#     optional int64 objectidps3;
#     optional float sgmag3;
#     optional float srmag3;
#     optional float simag3;
#     optional float szmag3;
#     optional float sgscore3;
#     optional float distpsnr3;
#     optional int32 nmtchps;
#     optional int64 rfid;
#     optional double jdstartref;
#     optional double jdendref;
#     optional int32 nframesref;
#     optional binary rbversion (UTF8);
#     optional float dsnrms;
#     optional float ssnrms;
#     optional float dsdiff;
#     optional float magzpsci;
#     optional float magzpsciunc;
#     optional float magzpscirms;
#     optional int32 nmatches;
#     optional float clrcoeff;
#     optional float clrcounc;
#     optional float zpclrcov;
#     optional float zpmed;
#     optional float clrmed;
#     optional float clrrms;
#     optional float neargaia;
#     optional float neargaiabright;
#     optional float maggaia;
#     optional float maggaiabright;
#     optional float exptime;
#     optional float drb;
#     optional binary drbversion (UTF8);
#   }
#   optional group prv_candidates (LIST) {
#     repeated group list {
#       optional group element {
#         optional double jd;
#         optional int32 fid;
#         optional int64 pid;
#         optional float diffmaglim;
#         optional binary pdiffimfilename (UTF8);
#         optional binary programpi (UTF8);
#         optional int32 programid;
#         optional int64 candid;
#         optional binary isdiffpos (UTF8);
#         optional int64 tblid;
#         optional int32 nid;
#         optional int32 rcid;
#         optional int32 field;
#         optional float xpos;
#         optional float ypos;
#         optional double ra;
#         optional double dec;
#         optional float magpsf;
#         optional float sigmapsf;
#         optional float chipsf;
#         optional float magap;
#         optional float sigmagap;
#         optional float distnr;
#         optional float magnr;
#         optional float sigmagnr;
#         optional float chinr;
#         optional float sharpnr;
#         optional float sky;
#         optional float magdiff;
#         optional float fwhm;
#         optional float classtar;
#         optional float mindtoedge;
#         optional float magfromlim;
#         optional float seeratio;
#         optional float aimage;
#         optional float bimage;
#         optional float aimagerat;
#         optional float bimagerat;
#         optional float elong;
#         optional int32 nneg;
#         optional int32 nbad;
#         optional float rb;
#         optional float ssdistnr;
#         optional float ssmagnr;
#         optional binary ssnamenr (UTF8);
#         optional float sumrat;
#         optional float magapbig;
#         optional float sigmagapbig;
#         optional double ranr;
#         optional double decnr;
#         optional double scorr;
#         optional float magzpsci;
#         optional float magzpsciunc;
#         optional float magzpscirms;
#         optional float clrcoeff;
#         optional float clrcounc;
#         optional binary rbversion (UTF8);
#       }
#     }
#   }
# }
#
# Catalyst form:
# StructType(StructField(objectId,StringType,true), StructField(candidate,StructType(StructField(jd,DoubleType,true), StructField(fid,IntegerType,true), StructField(pid,LongType,true), StructField(diffmaglim,FloatType,true), StructField(pdiffimfilename,StringType,true), StructField(programpi,StringType,true), StructField(programid,IntegerType,true), StructField(candid,LongType,true), StructField(isdiffpos,StringType,true), StructField(tblid,LongType,true), StructField(nid,IntegerType,true), StructField(rcid,IntegerType,true), StructField(field,IntegerType,true), StructField(xpos,FloatType,true), StructField(ypos,FloatType,true), StructField(ra,DoubleType,true), StructField(dec,DoubleType,true), StructField(magpsf,FloatType,true), StructField(sigmapsf,FloatType,true), StructField(chipsf,FloatType,true), StructField(magap,FloatType,true), StructField(sigmagap,FloatType,true), StructField(distnr,FloatType,true), StructField(magnr,FloatType,true), StructField(sigmagnr,FloatType,true), StructField(chinr,FloatType,true), StructField(sharpnr,FloatType,true), StructField(sky,FloatType,true), StructField(magdiff,FloatType,true), StructField(fwhm,FloatType,true), StructField(classtar,FloatType,true), StructField(mindtoedge,FloatType,true), StructField(magfromlim,FloatType,true), StructField(seeratio,FloatType,true), StructField(aimage,FloatType,true), StructField(bimage,FloatType,true), StructField(aimagerat,FloatType,true), StructField(bimagerat,FloatType,true), StructField(elong,FloatType,true), StructField(nneg,IntegerType,true), StructField(nbad,IntegerType,true), StructField(rb,FloatType,true), StructField(ssdistnr,FloatType,true), StructField(ssmagnr,FloatType,true), StructField(ssnamenr,StringType,true), StructField(sumrat,FloatType,true), StructField(magapbig,FloatType,true), StructField(sigmagapbig,FloatType,true), StructField(ranr,DoubleType,true), StructField(decnr,DoubleType,true), StructField(sgmag1,FloatType,true), StructField(srmag1,FloatType,true), StructField(simag1,FloatType,true), StructField(szmag1,FloatType,true), StructField(sgscore1,FloatType,true), StructField(distpsnr1,FloatType,true), StructField(ndethist,IntegerType,true), StructField(ncovhist,IntegerType,true), StructField(jdstarthist,DoubleType,true), StructField(jdendhist,DoubleType,true), StructField(scorr,DoubleType,true), StructField(tooflag,IntegerType,true), StructField(objectidps1,LongType,true), StructField(objectidps2,LongType,true), StructField(sgmag2,FloatType,true), StructField(srmag2,FloatType,true), StructField(simag2,FloatType,true), StructField(szmag2,FloatType,true), StructField(sgscore2,FloatType,true), StructField(distpsnr2,FloatType,true), StructField(objectidps3,LongType,true), StructField(sgmag3,FloatType,true), StructField(srmag3,FloatType,true), StructField(simag3,FloatType,true), StructField(szmag3,FloatType,true), StructField(sgscore3,FloatType,true), StructField(distpsnr3,FloatType,true), StructField(nmtchps,IntegerType,true), StructField(rfid,LongType,true), StructField(jdstartref,DoubleType,true), StructField(jdendref,DoubleType,true), StructField(nframesref,IntegerType,true), StructField(rbversion,StringType,true), StructField(dsnrms,FloatType,true), StructField(ssnrms,FloatType,true), StructField(dsdiff,FloatType,true), StructField(magzpsci,FloatType,true), StructField(magzpsciunc,FloatType,true), StructField(magzpscirms,FloatType,true), StructField(nmatches,IntegerType,true), StructField(clrcoeff,FloatType,true), StructField(clrcounc,FloatType,true), StructField(zpclrcov,FloatType,true), StructField(zpmed,FloatType,true), StructField(clrmed,FloatType,true), StructField(clrrms,FloatType,true), StructField(neargaia,FloatType,true), StructField(neargaiabright,FloatType,true), StructField(maggaia,FloatType,true), StructField(maggaiabright,FloatType,true), StructField(exptime,FloatType,true), StructField(drb,FloatType,true), StructField(drbversion,StringType,true)),true), StructField(prv_candidates,ArrayType(StructType(StructField(jd ...
#
# 22/01/24 01:28:17 INFO InternalParquetRecordReader: RecordReader initialized will read a total of 100 records.
# 22/01/24 01:28:17 INFO ParquetReadSupport: Going to read the following fields from the Parquet file:
#
# Parquet form:
# message spark_schema {
#   optional binary objectId (UTF8);
#   optional group candidate {
#     optional double jd;
#     optional int32 fid;
#     optional int64 pid;
#     optional float diffmaglim;
#     optional binary pdiffimfilename (UTF8);
#     optional binary programpi (UTF8);
#     optional int32 programid;
#     optional int64 candid;
#     optional binary isdiffpos (UTF8);
#     optional int64 tblid;
#     optional int32 nid;
#     optional int32 rcid;
#     optional int32 field;
#     optional float xpos;
#     optional float ypos;
#     optional double ra;
#     optional double dec;
#     optional float magpsf;
#     optional float sigmapsf;
#     optional float chipsf;
#     optional float magap;
#     optional float sigmagap;
#     optional float distnr;
#     optional float magnr;
#     optional float sigmagnr;
#     optional float chinr;
#     optional float sharpnr;
#     optional float sky;
#     optional float magdiff;
#     optional float fwhm;
#     optional float classtar;
#     optional float mindtoedge;
#     optional float magfromlim;
#     optional float seeratio;
#     optional float aimage;
#     optional float bimage;
#     optional float aimagerat;
#     optional float bimagerat;
#     optional float elong;
#     optional int32 nneg;
#     optional int32 nbad;
#     optional float rb;
#     optional float ssdistnr;
#     optional float ssmagnr;
#     optional binary ssnamenr (UTF8);
#     optional float sumrat;
#     optional float magapbig;
#     optional float sigmagapbig;
#     optional double ranr;
#     optional double decnr;
#     optional float sgmag1;
#     optional float srmag1;
#     optional float simag1;
#     optional float szmag1;
#     optional float sgscore1;
#     optional float distpsnr1;
#     optional int32 ndethist;
#     optional int32 ncovhist;
#     optional double jdstarthist;
#     optional double jdendhist;
#     optional double scorr;
#     optional int32 tooflag;
#     optional int64 objectidps1;
#     optional int64 objectidps2;
#     optional float sgmag2;
#     optional float srmag2;
#     optional float simag2;
#     optional float szmag2;
#     optional float sgscore2;
#     optional float distpsnr2;
#     optional int64 objectidps3;
#     optional float sgmag3;
#     optional float srmag3;
#     optional float simag3;
#     optional float szmag3;
#     optional float sgscore3;
#     optional float distpsnr3;
#     optional int32 nmtchps;
#     optional int64 rfid;
#     optional double jdstartref;
#     optional double jdendref;
#     optional int32 nframesref;
#     optional binary rbversion (UTF8);
#     optional float dsnrms;
#     optional float ssnrms;
#     optional float dsdiff;
#     optional float magzpsci;
#     optional float magzpsciunc;
#     optional float magzpscirms;
#     optional int32 nmatches;
#     optional float clrcoeff;
#     optional float clrcounc;
#     optional float zpclrcov;
#     optional float zpmed;
#     optional float clrmed;
#     optional float clrrms;
#     optional float neargaia;
#     optional float neargaiabright;
#     optional float maggaia;
#     optional float maggaiabright;
#     optional float exptime;
#     optional float drb;
#     optional binary drbversion (UTF8);
#   }
#   optional group prv_candidates (LIST) {
#     repeated group list {
#       optional group element {
#         optional double jd;
#         optional int32 fid;
#         optional int64 pid;
#         optional float diffmaglim;
#         optional binary pdiffimfilename (UTF8);
#         optional binary programpi (UTF8);
#         optional int32 programid;
#         optional int64 candid;
#         optional binary isdiffpos (UTF8);
#         optional int64 tblid;
#         optional int32 nid;
#         optional int32 rcid;
#         optional int32 field;
#         optional float xpos;
#         optional float ypos;
#         optional double ra;
#         optional double dec;
#         optional float magpsf;
#         optional float sigmapsf;
#         optional float chipsf;
#         optional float magap;
#         optional float sigmagap;
#         optional float distnr;
#         optional float magnr;
#         optional float sigmagnr;
#         optional float chinr;
#         optional float sharpnr;
#         optional float sky;
#         optional float magdiff;
#         optional float fwhm;
#         optional float classtar;
#         optional float mindtoedge;
#         optional float magfromlim;
#         optional float seeratio;
#         optional float aimage;
#         optional float bimage;
#         optional float aimagerat;
#         optional float bimagerat;
#         optional float elong;
#         optional int32 nneg;
#         optional int32 nbad;
#         optional float rb;
#         optional float ssdistnr;
#         optional float ssmagnr;
#         optional binary ssnamenr (UTF8);
#         optional float sumrat;
#         optional float magapbig;
#         optional float sigmagapbig;
#         optional double ranr;
#         optional double decnr;
#         optional double scorr;
#         optional float magzpsci;
#         optional float magzpsciunc;
#         optional float magzpscirms;
#         optional float clrcoeff;
#         optional float clrcounc;
#         optional binary rbversion (UTF8);
#       }
#     }
#   }
# }
#
# Catalyst form:
# StructType(StructField(objectId,StringType,true), StructField(candidate,StructType(StructField(jd,DoubleType,true), StructField(fid,IntegerType,true), StructField(pid,LongType,true), StructField(diffmaglim,FloatType,true), StructField(pdiffimfilename,StringType,true), StructField(programpi,StringType,true), StructField(programid,IntegerType,true), StructField(candid,LongType,true), StructField(isdiffpos,StringType,true), StructField(tblid,LongType,true), StructField(nid,IntegerType,true), StructField(rcid,IntegerType,true), StructField(field,IntegerType,true), StructField(xpos,FloatType,true), StructField(ypos,FloatType,true), StructField(ra,DoubleType,true), StructField(dec,DoubleType,true), StructField(magpsf,FloatType,true), StructField(sigmapsf,FloatType,true), StructField(chipsf,FloatType,true), StructField(magap,FloatType,true), StructField(sigmagap,FloatType,true), StructField(distnr,FloatType,true), StructField(magnr,FloatType,true), StructField(sigmagnr,FloatType,true), StructField(chinr,FloatType,true), StructField(sharpnr,FloatType,true), StructField(sky,FloatType,true), StructField(magdiff,FloatType,true), StructField(fwhm,FloatType,true), StructField(classtar,FloatType,true), StructField(mindtoedge,FloatType,true), StructField(magfromlim,FloatType,true), StructField(seeratio,FloatType,true), StructField(aimage,FloatType,true), StructField(bimage,FloatType,true), StructField(aimagerat,FloatType,true), StructField(bimagerat,FloatType,true), StructField(elong,FloatType,true), StructField(nneg,IntegerType,true), StructField(nbad,IntegerType,true), StructField(rb,FloatType,true), StructField(ssdistnr,FloatType,true), StructField(ssmagnr,FloatType,true), StructField(ssnamenr,StringType,true), StructField(sumrat,FloatType,true), StructField(magapbig,FloatType,true), StructField(sigmagapbig,FloatType,true), StructField(ranr,DoubleType,true), StructField(decnr,DoubleType,true), StructField(sgmag1,FloatType,true), StructField(srmag1,FloatType,true), StructField(simag1,FloatType,true), StructField(szmag1,FloatType,true), StructField(sgscore1,FloatType,true), StructField(distpsnr1,FloatType,true), StructField(ndethist,IntegerType,true), StructField(ncovhist,IntegerType,true), StructField(jdstarthist,DoubleType,true), StructField(jdendhist,DoubleType,true), StructField(scorr,DoubleType,true), StructField(tooflag,IntegerType,true), StructField(objectidps1,LongType,true), StructField(objectidps2,LongType,true), StructField(sgmag2,FloatType,true), StructField(srmag2,FloatType,true), StructField(simag2,FloatType,true), StructField(szmag2,FloatType,true), StructField(sgscore2,FloatType,true), StructField(distpsnr2,FloatType,true), StructField(objectidps3,LongType,true), StructField(sgmag3,FloatType,true), StructField(srmag3,FloatType,true), StructField(simag3,FloatType,true), StructField(szmag3,FloatType,true), StructField(sgscore3,FloatType,true), StructField(distpsnr3,FloatType,true), StructField(nmtchps,IntegerType,true), StructField(rfid,LongType,true), StructField(jdstartref,DoubleType,true), StructField(jdendref,DoubleType,true), StructField(nframesref,IntegerType,true), StructField(rbversion,StringType,true), StructField(dsnrms,FloatType,true), StructField(ssnrms,FloatType,true), StructField(dsdiff,FloatType,true), StructField(magzpsci,FloatType,true), StructField(magzpsciunc,FloatType,true), StructField(magzpscirms,FloatType,true), StructField(nmatches,IntegerType,true), StructField(clrcoeff,FloatType,true), StructField(clrcounc,FloatType,true), StructField(zpclrcov,FloatType,true), StructField(zpmed,FloatType,true), StructField(clrmed,FloatType,true), StructField(clrrms,FloatType,true), StructField(neargaia,FloatType,true), StructField(neargaiabright,FloatType,true), StructField(maggaia,FloatType,true), StructField(maggaiabright,FloatType,true), StructField(exptime,FloatType,true), StructField(drb,FloatType,true), StructField(drbversion,StringType,true)),true), StructField(prv_candidates,ArrayType(StructType(StructField(jd ...
#
# 22/01/24 01:28:17 INFO FileScanRDD: Reading File path: file:///Users/igor/Work/snad/fink-science/fink_science/snad/sample.parquet/part-00001-c66c93e0-4980-4dcf-bee1-166ecf780e07-c000.snappy.parquet, range: 0-2941305, partition values: [empty row]
# 22/01/24 01:28:17 INFO InternalParquetRecordReader: RecordReader initialized will read a total of 57 records.
# 22/01/24 01:28:17 INFO FileScanRDD: Reading File path: file:///Users/igor/Work/snad/fink-science/fink_science/snad/sample.parquet/part-00002-c66c93e0-4980-4dcf-bee1-166ecf780e07-c000.snappy.parquet, range: 0-4194304, partition values: [empty row]
# 22/01/24 01:28:17 INFO InternalParquetRecordReader: at row 0. reading next block
# 22/01/24 01:28:17 INFO InternalParquetRecordReader: RecordReader initialized will read a total of 0 records.
# 22/01/24 01:28:17 INFO InternalParquetRecordReader: block read in memory in 5 ms. row count = 100
# 22/01/24 01:28:17 INFO InternalParquetRecordReader: at row 0. reading next block
# 22/01/24 01:28:17 INFO ParquetReadSupport: Going to read the following fields from the Parquet file:
#
# Parquet form:
# message spark_schema {
#   optional binary objectId (UTF8);
#   optional group candidate {
#     optional double jd;
#     optional int32 fid;
#     optional int64 pid;
#     optional float diffmaglim;
#     optional binary pdiffimfilename (UTF8);
#     optional binary programpi (UTF8);
#     optional int32 programid;
#     optional int64 candid;
#     optional binary isdiffpos (UTF8);
#     optional int64 tblid;
#     optional int32 nid;
#     optional int32 rcid;
#     optional int32 field;
#     optional float xpos;
#     optional float ypos;
#     optional double ra;
#     optional double dec;
#     optional float magpsf;
#     optional float sigmapsf;
#     optional float chipsf;
#     optional float magap;
#     optional float sigmagap;
#     optional float distnr;
#     optional float magnr;
#     optional float sigmagnr;
#     optional float chinr;
#     optional float sharpnr;
#     optional float sky;
#     optional float magdiff;
#     optional float fwhm;
#     optional float classtar;
#     optional float mindtoedge;
#     optional float magfromlim;
#     optional float seeratio;
#     optional float aimage;
#     optional float bimage;
#     optional float aimagerat;
#     optional float bimagerat;
#     optional float elong;
#     optional int32 nneg;
#     optional int32 nbad;
#     optional float rb;
#     optional float ssdistnr;
#     optional float ssmagnr;
#     optional binary ssnamenr (UTF8);
#     optional float sumrat;
#     optional float magapbig;
#     optional float sigmagapbig;
#     optional double ranr;
#     optional double decnr;
#     optional float sgmag1;
#     optional float srmag1;
#     optional float simag1;
#     optional float szmag1;
#     optional float sgscore1;
#     optional float distpsnr1;
#     optional int32 ndethist;
#     optional int32 ncovhist;
#     optional double jdstarthist;
#     optional double jdendhist;
#     optional double scorr;
#     optional int32 tooflag;
#     optional int64 objectidps1;
#     optional int64 objectidps2;
#     optional float sgmag2;
#     optional float srmag2;
#     optional float simag2;
#     optional float szmag2;
#     optional float sgscore2;
#     optional float distpsnr2;
#     optional int64 objectidps3;
#     optional float sgmag3;
#     optional float srmag3;
#     optional float simag3;
#     optional float szmag3;
#     optional float sgscore3;
#     optional float distpsnr3;
#     optional int32 nmtchps;
#     optional int64 rfid;
#     optional double jdstartref;
#     optional double jdendref;
#     optional int32 nframesref;
#     optional binary rbversion (UTF8);
#     optional float dsnrms;
#     optional float ssnrms;
#     optional float dsdiff;
#     optional float magzpsci;
#     optional float magzpsciunc;
#     optional float magzpscirms;
#     optional int32 nmatches;
#     optional float clrcoeff;
#     optional float clrcounc;
#     optional float zpclrcov;
#     optional float zpmed;
#     optional float clrmed;
#     optional float clrrms;
#     optional float neargaia;
#     optional float neargaiabright;
#     optional float maggaia;
#     optional float maggaiabright;
#     optional float exptime;
#     optional float drb;
#     optional binary drbversion (UTF8);
#   }
#   optional group prv_candidates (LIST) {
#     repeated group list {
#       optional group element {
#         optional double jd;
#         optional int32 fid;
#         optional int64 pid;
#         optional float diffmaglim;
#         optional binary pdiffimfilename (UTF8);
#         optional binary programpi (UTF8);
#         optional int32 programid;
#         optional int64 candid;
#         optional binary isdiffpos (UTF8);
#         optional int64 tblid;
#         optional int32 nid;
#         optional int32 rcid;
#         optional int32 field;
#         optional float xpos;
#         optional float ypos;
#         optional double ra;
#         optional double dec;
#         optional float magpsf;
#         optional float sigmapsf;
#         optional float chipsf;
#         optional float magap;
#         optional float sigmagap;
#         optional float distnr;
#         optional float magnr;
#         optional float sigmagnr;
#         optional float chinr;
#         optional float sharpnr;
#         optional float sky;
#         optional float magdiff;
#         optional float fwhm;
#         optional float classtar;
#         optional float mindtoedge;
#         optional float magfromlim;
#         optional float seeratio;
#         optional float aimage;
#         optional float bimage;
#         optional float aimagerat;
#         optional float bimagerat;
#         optional float elong;
#         optional int32 nneg;
#         optional int32 nbad;
#         optional float rb;
#         optional float ssdistnr;
#         optional float ssmagnr;
#         optional binary ssnamenr (UTF8);
#         optional float sumrat;
#         optional float magapbig;
#         optional float sigmagapbig;
#         optional double ranr;
#         optional double decnr;
#         optional double scorr;
#         optional float magzpsci;
# ...
#
# 22/01/24 01:28:17 INFO InternalParquetRecordReader: block read in memory in 5 ms. row count = 57
# 22/01/24 01:28:17 INFO ParquetReadSupport: Going to read the following fields from the Parquet file:
#
# Parquet form:
# message spark_schema {
#   optional binary objectId (UTF8);
#   optional group candidate {
#     optional double jd;
#     optional int32 fid;
#     optional int64 pid;
#     optional float diffmaglim;
#     optional binary pdiffimfilename (UTF8);
#     optional binary programpi (UTF8);
#     optional int32 programid;
#     optional int64 candid;
#     optional binary isdiffpos (UTF8);
#     optional int64 tblid;
#     optional int32 nid;
#     optional int32 rcid;
#     optional int32 field;
#     optional float xpos;
#     optional float ypos;
#     optional double ra;
#     optional double dec;
#     optional float magpsf;
#     optional float sigmapsf;
#     optional float chipsf;
#     optional float magap;
#     optional float sigmagap;
#     optional float distnr;
#     optional float magnr;
#     optional float sigmagnr;
#     optional float chinr;
#     optional float sharpnr;
#     optional float sky;
#     optional float magdiff;
#     optional float fwhm;
#     optional float classtar;
#     optional float mindtoedge;
#     optional float magfromlim;
#     optional float seeratio;
#     optional float aimage;
#     optional float bimage;
#     optional float aimagerat;
#     optional float bimagerat;
#     optional float elong;
#     optional int32 nneg;
#     optional int32 nbad;
#     optional float rb;
#     optional float ssdistnr;
#     optional float ssmagnr;
#     optional binary ssnamenr (UTF8);
#     optional float sumrat;
#     optional float magapbig;
#     optional float sigmagapbig;
#     optional double ranr;
#     optional double decnr;
#     optional float sgmag1;
#     optional float srmag1;
#     optional float simag1;
#     optional float szmag1;
#     optional float sgscore1;
#     optional float distpsnr1;
#     optional int32 ndethist;
#     optional int32 ncovhist;
#     optional double jdstarthist;
#     optional double jdendhist;
#     optional double scorr;
#     optional int32 tooflag;
#     optional int64 objectidps1;
#     optional int64 objectidps2;
#     optional float sgmag2;
#     optional float srmag2;
#     optional float simag2;
#     optional float szmag2;
#     optional float sgscore2;
#     optional float distpsnr2;
#     optional int64 objectidps3;
#     optional float sgmag3;
#     optional float srmag3;
#     optional float simag3;
#     optional float szmag3;
#     optional float sgscore3;
#     optional float distpsnr3;
#     optional int32 nmtchps;
#     optional int64 rfid;
#     optional double jdstartref;
#     optional double jdendref;
#     optional int32 nframesref;
#     optional binary rbversion (UTF8);
#     optional float dsnrms;
#     optional float ssnrms;
#     optional float dsdiff;
#     optional float magzpsci;
#     optional float magzpsciunc;
#     optional float magzpscirms;
#     optional int32 nmatches;
#     optional float clrcoeff;
#     optional float clrcounc;
#     optional float zpclrcov;
#     optional float zpmed;
#     optional float clrmed;
#     optional float clrrms;
#     optional float neargaia;
#     optional float neargaiabright;
#     optional float maggaia;
#     optional float maggaiabright;
#     optional float exptime;
#     optional float drb;
#     optional binary drbversion (UTF8);
#   }
#   optional group prv_candidates (LIST) {
#     repeated group list {
#       optional group element {
#         optional double jd;
#         optional int32 fid;
#         optional int64 pid;
#         optional float diffmaglim;
#         optional binary pdiffimfilename (UTF8);
#         optional binary programpi (UTF8);
#         optional int32 programid;
#         optional int64 candid;
#         optional binary isdiffpos (UTF8);
#         optional int64 tblid;
#         optional int32 nid;
#         optional int32 rcid;
#         optional int32 field;
#         optional float xpos;
#         optional float ypos;
#         optional double ra;
#         optional double dec;
#         optional float magpsf;
#         optional float sigmapsf;
#         optional float chipsf;
#         optional float magap;
#         optional float sigmagap;
#         optional float distnr;
#         optional float magnr;
#         optional float sigmagnr;
#         optional float chinr;
#         optional float sharpnr;
#         optional float sky;
#         optional float magdiff;
#         optional float fwhm;
#         optional float classtar;
#         optional float mindtoedge;
#         optional float magfromlim;
#         optional float seeratio;
#         optional float aimage;
#         optional float bimage;
#         optional float aimagerat;
#         optional float bimagerat;
#         optional float elong;
#         optional int32 nneg;
#         optional int32 nbad;
#         optional float rb;
#         optional float ssdistnr;
#         optional float ssmagnr;
#         optional binary ssnamenr (UTF8);
#         optional float sumrat;
#         optional float magapbig;
#         optional float sigmagapbig;
#         optional double ranr;
#         optional double decnr;
#         optional double scorr;
#         optional float magzpsci;
#         optional float magzpsciunc;
#         optional float magzpscirms;
#         optional float clrcoeff;
#         optional float clrcounc;
#         optional binary rbversion (UTF8);
#       }
#     }
#   }
# }
#
# Catalyst form:
# StructType(StructField(objectId,StringType,true), StructField(candidate,StructType(StructField(jd,DoubleType,true), StructField(fid,IntegerType,true), StructField(pid,LongType,true), StructField(diffmaglim,FloatType,true), StructField(pdiffimfilename,StringType,true), StructField(programpi,StringType,true), StructField(programid,IntegerType,true), StructField(candid,LongType,true), StructField(isdiffpos,StringType,true), StructField(tblid,LongType,true), StructField(nid,IntegerType,true), StructField(rcid,IntegerType,true), StructField(field,IntegerType,true), StructField(xpos,FloatType,true), StructField(ypos,FloatType,true), StructField(ra,DoubleType,true), StructField(dec,DoubleType,true), StructField(magpsf,FloatType,true), StructField(sigmapsf,FloatType,true), StructField(chipsf,FloatType,true), StructField(magap,FloatType,true), StructField(sigmagap,FloatType,true), StructField(distnr,FloatType,true), StructField(magnr,FloatType,true), StructField(sigmagnr,FloatType,true), StructField(chinr,FloatType,true), StructField(sharpnr,FloatType,true), StructField(sky,FloatType,true), StructField(magdiff,FloatType,true), StructField(fwhm,FloatType,true), StructField(classtar,FloatType,true), StructField(mindtoedge,FloatType,true), StructField(magfromlim,FloatType,true), StructField(seeratio,FloatType,true), StructField(aimage,FloatType,true), StructField(bimage,FloatType,true), StructField(aimagerat,FloatType,true), StructField(bimagerat,FloatType,true), StructField(elong,FloatType,true), StructField(nneg,IntegerType,true), StructField(nbad,IntegerType,true), StructField(rb,FloatType,true), StructField(ssdistnr,FloatType,true), StructField(ssmagnr,FloatType,true), StructField(ssnamenr,StringType,true), StructField(sumrat,FloatType,true), StructField(magapbig,FloatType,true), StructField(sigmagapbig,FloatType,true), StructField(ranr,DoubleType,true), StructField(decnr,DoubleType,true), StructField(sgmag1,FloatType,true), StructField(srmag1,FloatType,true), StructField(simag1,FloatType,true), StructField(szmag1,FloatType,true), StructField(sgscore1,FloatType,true), StructField(distpsnr1,FloatType,true), StructField(ndethist,IntegerType,true), StructField(ncovhist,IntegerType,true), StructField(jdstarthist,DoubleType,true), StructField(jdendhist,DoubleType,true), StructField(scorr,DoubleType,true), StructField(tooflag,IntegerType,true), StructField(objectidps1,LongType,true), StructField(objectidps2,LongType,true), StructField(sgmag2,FloatType,true), StructField(srmag2,FloatType,true), StructField(simag2,FloatType,true), StructField(szmag2,FloatType,true), StructField(sgscore2,FloatType,true), StructField(distpsnr2,FloatType,true), StructField(objectidps3,LongType,true), StructField(sgmag3,FloatType,true), StructField(srmag3,FloatType,true), StructField(simag3,FloatType,true), StructField(szmag3,FloatType,true), StructField(sgscore3,FloatType,true), StructField(distpsnr3,FloatType,true), StructField(nmtchps,IntegerType,true), StructField(rfid,LongType,true), StructField(jdstartref,DoubleType,true), StructField(jdendref,DoubleType,true), StructField(nframesref,IntegerType,true), StructField(rbversion,StringType,true), StructField(dsnrms,FloatType,true), StructField(ssnrms,FloatType,true), StructField(dsdiff,FloatType,true), StructField(magzpsci,FloatType,true), StructField(magzpsciunc,FloatType,true), StructField(magzpscirms,FloatType,true), StructField(nmatches,IntegerType,true), StructField(clrcoeff,FloatType,true), StructField(clrcounc,FloatType,true), StructField(zpclrcov,FloatType,true), StructField(zpmed,FloatType,true), StructField(clrmed,FloatType,true), StructField(clrrms,FloatType,true), StructField(neargaia,FloatType,true), StructField(neargaiabright,FloatType,true), StructField(maggaia,FloatType,true), StructField(maggaiabright,FloatType,true), StructField(exptime,FloatType,true), StructField(drb,FloatType,true), StructField(drbversion,StringType,true)),true), StructField(prv_candidates,ArrayType(StructType(StructField(jd ...
#
# 22/01/24 01:28:17 INFO InternalParquetRecordReader: RecordReader initialized will read a total of 0 records.
# 22/01/24 01:28:17 INFO InternalParquetRecordReader: RecordReader initialized will read a total of 67 records.
# 22/01/24 01:28:18 INFO InternalParquetRecordReader: RecordReader initialized will read a total of 96 records.
# 22/01/24 01:28:18 INFO InternalParquetRecordReader: at row 0. reading next block
# 22/01/24 01:28:18 INFO InternalParquetRecordReader: block read in memory in 4 ms. row count = 67
# 22/01/24 01:28:18 INFO InternalParquetRecordReader: at row 0. reading next block
# 22/01/24 01:28:18 INFO InternalParquetRecordReader: block read in memory in 3 ms. row count = 96
# 22/01/24 01:28:19 INFO ArrowPythonRunner: Times: total = 1517, boot = 20, init = 1497, finish = 0
# 22/01/24 01:28:19 INFO ArrowPythonRunner: Times: total = 1517, boot = 14, init = 1503, finish = 0
# 22/01/24 01:28:19 INFO Executor: Finished task 4.0 in stage 26.0 (TID 65). 2134 bytes result sent to driver
# 22/01/24 01:28:19 INFO Executor: Finished task 5.0 in stage 26.0 (TID 66). 2134 bytes result sent to driver
# 22/01/24 01:28:19 INFO TaskSetManager: Finished task 4.0 in stage 26.0 (TID 65) in 1567 ms on localhost (executor driver) (1/6)
# 22/01/24 01:28:19 INFO TaskSetManager: Finished task 5.0 in stage 26.0 (TID 66) in 1568 ms on localhost (executor driver) (2/6)
# 22/01/24 01:28:19 INFO ArrowPythonRunner: Times: total = 1608, boot = 8, init = 1508, finish = 92
# 22/01/24 01:28:19 INFO Executor: Finished task 3.0 in stage 26.0 (TID 64). 10039 bytes result sent to driver
# 22/01/24 01:28:19 INFO TaskSetManager: Finished task 3.0 in stage 26.0 (TID 64) in 1674 ms on localhost (executor driver) (3/6)
# 22/01/24 01:28:19 INFO ArrowPythonRunner: Times: total = 1624, boot = 30, init = 1487, finish = 107
# 22/01/24 01:28:19 INFO Executor: Finished task 2.0 in stage 26.0 (TID 63). 13625 bytes result sent to driver
# 22/01/24 01:28:19 INFO TaskSetManager: Finished task 2.0 in stage 26.0 (TID 63) in 1692 ms on localhost (executor driver) (4/6)
# 22/01/24 01:28:19 INFO ArrowPythonRunner: Times: total = 1732, boot = 41, init = 1477, finish = 214
# 22/01/24 01:28:19 INFO Executor: Finished task 1.0 in stage 26.0 (TID 62). 17351 bytes result sent to driver
# 22/01/24 01:28:19 INFO TaskSetManager: Finished task 1.0 in stage 26.0 (TID 62) in 1789 ms on localhost (executor driver) (5/6)
# 22/01/24 01:28:19 INFO ArrowPythonRunner: Times: total = 1743, boot = 6, init = 1513, finish = 224
# 22/01/24 01:28:19 INFO Executor: Finished task 0.0 in stage 26.0 (TID 61). 19367 bytes result sent to driver
# 22/01/24 01:28:19 INFO TaskSetManager: Finished task 0.0 in stage 26.0 (TID 61) in 1804 ms on localhost (executor driver) (6/6)
# 22/01/24 01:28:19 INFO TaskSchedulerImpl: Removed TaskSet 26.0, whose tasks have all completed, from pool
# 22/01/24 01:28:19 INFO DAGScheduler: ResultStage 26 (toPandas at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/3795175238.py:22) finished in 1,808 s
# 22/01/24 01:28:19 INFO DAGScheduler: Job 26 finished: toPandas at /var/folders/0d/6k64288x2n7154c7n780k0j00000gn/T/ipykernel_85404/3795175238.py:22, took 1,810890 s

# %% [markdown]
# We can also quickly check some statistics on this new column:

# %%
df_change.select('deltamag').describe().show()
# Out:
# +-------+-------------------+
# |summary|           deltamag|
# +-------+-------------------+
# |  count|                176|
# |   mean|0.09352213686162775|
# | stddev| 0.9564824046920042|
# |    min| -2.828317642211914|
# |    max| 3.4397459030151367|
# +-------+-------------------+

# %%
df.printSchema()
# Out:
# root
#  |-- candid: long (nullable = true)
#  |-- schemavsn: string (nullable = true)
#  |-- publisher: string (nullable = true)
#  |-- objectId: string (nullable = true)
#  |-- candidate: struct (nullable = true)
#  |    |-- jd: double (nullable = true)
#  |    |-- fid: integer (nullable = true)
#  |    |-- pid: long (nullable = true)
#  |    |-- diffmaglim: float (nullable = true)
#  |    |-- pdiffimfilename: string (nullable = true)
#  |    |-- programpi: string (nullable = true)
#  |    |-- programid: integer (nullable = true)
#  |    |-- candid: long (nullable = true)
#  |    |-- isdiffpos: string (nullable = true)
#  |    |-- tblid: long (nullable = true)
#  |    |-- nid: integer (nullable = true)
#  |    |-- rcid: integer (nullable = true)
#  |    |-- field: integer (nullable = true)
#  |    |-- xpos: float (nullable = true)
#  |    |-- ypos: float (nullable = true)
#  |    |-- ra: double (nullable = true)
#  |    |-- dec: double (nullable = true)
#  |    |-- magpsf: float (nullable = true)
#  |    |-- sigmapsf: float (nullable = true)
#  |    |-- chipsf: float (nullable = true)
#  |    |-- magap: float (nullable = true)
#  |    |-- sigmagap: float (nullable = true)
#  |    |-- distnr: float (nullable = true)
#  |    |-- magnr: float (nullable = true)
#  |    |-- sigmagnr: float (nullable = true)
#  |    |-- chinr: float (nullable = true)
#  |    |-- sharpnr: float (nullable = true)
#  |    |-- sky: float (nullable = true)
#  |    |-- magdiff: float (nullable = true)
#  |    |-- fwhm: float (nullable = true)
#  |    |-- classtar: float (nullable = true)
#  |    |-- mindtoedge: float (nullable = true)
#  |    |-- magfromlim: float (nullable = true)
#  |    |-- seeratio: float (nullable = true)
#  |    |-- aimage: float (nullable = true)
#  |    |-- bimage: float (nullable = true)
#  |    |-- aimagerat: float (nullable = true)
#  |    |-- bimagerat: float (nullable = true)
#  |    |-- elong: float (nullable = true)
#  |    |-- nneg: integer (nullable = true)
#  |    |-- nbad: integer (nullable = true)
#  |    |-- rb: float (nullable = true)
#  |    |-- ssdistnr: float (nullable = true)
#  |    |-- ssmagnr: float (nullable = true)
#  |    |-- ssnamenr: string (nullable = true)
#  |    |-- sumrat: float (nullable = true)
#  |    |-- magapbig: float (nullable = true)
#  |    |-- sigmagapbig: float (nullable = true)
#  |    |-- ranr: double (nullable = true)
#  |    |-- decnr: double (nullable = true)
#  |    |-- sgmag1: float (nullable = true)
#  |    |-- srmag1: float (nullable = true)
#  |    |-- simag1: float (nullable = true)
#  |    |-- szmag1: float (nullable = true)
#  |    |-- sgscore1: float (nullable = true)
#  |    |-- distpsnr1: float (nullable = true)
#  |    |-- ndethist: integer (nullable = true)
#  |    |-- ncovhist: integer (nullable = true)
#  |    |-- jdstarthist: double (nullable = true)
#  |    |-- jdendhist: double (nullable = true)
#  |    |-- scorr: double (nullable = true)
#  |    |-- tooflag: integer (nullable = true)
#  |    |-- objectidps1: long (nullable = true)
#  |    |-- objectidps2: long (nullable = true)
#  |    |-- sgmag2: float (nullable = true)
#  |    |-- srmag2: float (nullable = true)
#  |    |-- simag2: float (nullable = true)
#  |    |-- szmag2: float (nullable = true)
#  |    |-- sgscore2: float (nullable = true)
#  |    |-- distpsnr2: float (nullable = true)
#  |    |-- objectidps3: long (nullable = true)
#  |    |-- sgmag3: float (nullable = true)
#  |    |-- srmag3: float (nullable = true)
#  |    |-- simag3: float (nullable = true)
#  |    |-- szmag3: float (nullable = true)
#  |    |-- sgscore3: float (nullable = true)
#  |    |-- distpsnr3: float (nullable = true)
#  |    |-- nmtchps: integer (nullable = true)
#  |    |-- rfid: long (nullable = true)
#  |    |-- jdstartref: double (nullable = true)
#  |    |-- jdendref: double (nullable = true)
#  |    |-- nframesref: integer (nullable = true)
#  |    |-- rbversion: string (nullable = true)
#  |    |-- dsnrms: float (nullable = true)
#  |    |-- ssnrms: float (nullable = true)
#  |    |-- dsdiff: float (nullable = true)
#  |    |-- magzpsci: float (nullable = true)
#  |    |-- magzpsciunc: float (nullable = true)
#  |    |-- magzpscirms: float (nullable = true)
#  |    |-- nmatches: integer (nullable = true)
#  |    |-- clrcoeff: float (nullable = true)
#  |    |-- clrcounc: float (nullable = true)
#  |    |-- zpclrcov: float (nullable = true)
#  |    |-- zpmed: float (nullable = true)
#  |    |-- clrmed: float (nullable = true)
#  |    |-- clrrms: float (nullable = true)
#  |    |-- neargaia: float (nullable = true)
#  |    |-- neargaiabright: float (nullable = true)
#  |    |-- maggaia: float (nullable = true)
#  |    |-- maggaiabright: float (nullable = true)
#  |    |-- exptime: float (nullable = true)
#  |    |-- drb: float (nullable = true)
#  |    |-- drbversion: string (nullable = true)
#  |-- prv_candidates: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- jd: double (nullable = true)
#  |    |    |-- fid: integer (nullable = true)
#  |    |    |-- pid: long (nullable = true)
#  |    |    |-- diffmaglim: float (nullable = true)
#  |    |    |-- pdiffimfilename: string (nullable = true)
#  |    |    |-- programpi: string (nullable = true)
#  |    |    |-- programid: integer (nullable = true)
#  |    |    |-- candid: long (nullable = true)
#  |    |    |-- isdiffpos: string (nullable = true)
#  |    |    |-- tblid: long (nullable = true)
#  |    |    |-- nid: integer (nullable = true)
#  |    |    |-- rcid: integer (nullable = true)
#  |    |    |-- field: integer (nullable = true)
#  |    |    |-- xpos: float (nullable = true)
#  |    |    |-- ypos: float (nullable = true)
#  |    |    |-- ra: double (nullable = true)
#  |    |    |-- dec: double (nullable = true)
#  |    |    |-- magpsf: float (nullable = true)
#  |    |    |-- sigmapsf: float (nullable = true)
#  |    |    |-- chipsf: float (nullable = true)
#  |    |    |-- magap: float (nullable = true)
#  |    |    |-- sigmagap: float (nullable = true)
#  |    |    |-- distnr: float (nullable = true)
#  |    |    |-- magnr: float (nullable = true)
#  |    |    |-- sigmagnr: float (nullable = true)
#  |    |    |-- chinr: float (nullable = true)
#  |    |    |-- sharpnr: float (nullable = true)
#  |    |    |-- sky: float (nullable = true)
#  |    |    |-- magdiff: float (nullable = true)
#  |    |    |-- fwhm: float (nullable = true)
#  |    |    |-- classtar: float (nullable = true)
#  |    |    |-- mindtoedge: float (nullable = true)
#  |    |    |-- magfromlim: float (nullable = true)
#  |    |    |-- seeratio: float (nullable = true)
#  |    |    |-- aimage: float (nullable = true)
#  |    |    |-- bimage: float (nullable = true)
#  |    |    |-- aimagerat: float (nullable = true)
#  |    |    |-- bimagerat: float (nullable = true)
#  |    |    |-- elong: float (nullable = true)
#  |    |    |-- nneg: integer (nullable = true)
#  |    |    |-- nbad: integer (nullable = true)
#  |    |    |-- rb: float (nullable = true)
#  |    |    |-- ssdistnr: float (nullable = true)
#  |    |    |-- ssmagnr: float (nullable = true)
#  |    |    |-- ssnamenr: string (nullable = true)
#  |    |    |-- sumrat: float (nullable = true)
#  |    |    |-- magapbig: float (nullable = true)
#  |    |    |-- sigmagapbig: float (nullable = true)
#  |    |    |-- ranr: double (nullable = true)
#  |    |    |-- decnr: double (nullable = true)
#  |    |    |-- scorr: double (nullable = true)
#  |    |    |-- magzpsci: float (nullable = true)
#  |    |    |-- magzpsciunc: float (nullable = true)
#  |    |    |-- magzpscirms: float (nullable = true)
#  |    |    |-- clrcoeff: float (nullable = true)
#  |    |    |-- clrcounc: float (nullable = true)
#  |    |    |-- rbversion: string (nullable = true)
#  |-- cutoutScience: struct (nullable = true)
#  |    |-- fileName: string (nullable = true)
#  |    |-- stampData: binary (nullable = true)
#  |-- cutoutTemplate: struct (nullable = true)
#  |    |-- fileName: string (nullable = true)
#  |    |-- stampData: binary (nullable = true)
#  |-- cutoutDifference: struct (nullable = true)
#  |    |-- fileName: string (nullable = true)
#  |    |-- stampData: binary (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- cdsxmatch: string (nullable = true)
#  |-- rfscore: double (nullable = true)
#  |-- snn_snia_vs_nonia: double (nullable = true)
#  |-- snn_sn_vs_all: double (nullable = true)
#  |-- mulens: struct (nullable = true)
#  |    |-- class_1: string (nullable = true)
#  |    |-- ml_score_1: double (nullable = true)
#  |    |-- class_2: string (nullable = true)
#  |    |-- ml_score_2: double (nullable = true)
#  |-- roid: integer (nullable = true)
#  |-- nalerthist: integer (nullable = true)
#  |-- knscore: double (nullable = true)
#  |-- fink_broker_version: string (nullable = true)
#  |-- fink_science_version: string (nullable = true)
#  |-- tracklet: string (nullable = true)
#  |-- cmagpsf: array (nullable = true)
#  |    |-- element: float (containsNull = true)
#  |-- cjd: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- csigmapsf: array (nullable = true)
#  |    |-- element: float (containsNull = true)
#  |-- cfid: array (nullable = true)
#  |    |-- element: integer (containsNull = true)
#  |-- lc_amplitude: double (nullable = true)
#  |-- lc_beyond_1_std: double (nullable = true)
#  |-- lc_linear_fit_slope: double (nullable = true)
#  |-- lc_linear_fit_slope_sigma: double (nullable = true)
#  |-- lc_linear_fit_reduced_chi2: double (nullable = true)
#  |-- lc_mean: double (nullable = true)
#  |-- lc_median: double (nullable = true)
#  |-- lc_standard_deviation: double (nullable = true)
#  |-- lc_cusum: double (nullable = true)
#  |-- lc_excess_variance: double (nullable = true)
#  |-- lc_mean_variance: double (nullable = true)
#  |-- lc_kurtosis: double (nullable = true)
#  |-- lc_maximum_slope: double (nullable = true)
#  |-- lc_skew: double (nullable = true)
#  |-- lc_eta: double (nullable = true)
#  |-- lc_anderson_darling_normal: double (nullable = true)
#  |-- lc_chi2: double (nullable = true)
#  |-- lc_inter_percentile_range_10: double (nullable = true)
#  |-- lc_median_buffer_range_percentage_10: double (nullable = true)
#  |-- lc_percent_difference_magnitude_percentile_10: double (nullable = true)
#  |-- lc_median_absolute_deviation: double (nullable = true)
#  |-- lc_percent_amplitude: double (nullable = true)
#  |-- lc_eta_e: double (nullable = true)
#  |-- lc_linear_trend: double (nullable = true)
#  |-- lc_linear_trend_sigma: double (nullable = true)
#  |-- lc_linear_trend_noise: double (nullable = true)
#  |-- lc_stetson_K: double (nullable = true)
#  |-- lc_weighted_mean: double (nullable = true)
#  |-- lc_magnitude_percentage_ratio_40_5: double (nullable = true)
#  |-- lc_magnitude_percentage_ratio_20_10: double (nullable = true)
